# %% [markdown]
# # Recurrent Neural Network
#
# In this exercise, we'll implement a 'vanilla' recurrent neural network and apply it to a character-level language modeling task.

# %%
# Setup and load data
import numpy as np
import os
data = file('D:/Azam/fall2015/DeepLearning/hw3/VT-F15-ECE6504-HW3-1.0/data/input.txt', 'r').read()
chars = list(set(data))
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }

# %%
class RNN:
    def __init__(self, input_size = 100, hidden_size = 100):
        self.input_size = input_size
        self.hidden_size = hidden_size

        self.W_xh = np.random.randn(self.hidden_size, self.input_size) * 0.01
        self.W_hh = np.random.randn(self.hidden_size, self.hidden_size) * 0.01
        self.W_hy = np.random.randn(self.input_size, self.hidden_size) * 0.01
        self.b_hh = np.zeros((self.hidden_size, 1))
        self.b_hy = np.zeros((self.input_size, 1))

# %% [markdown]
# ## Forward Pass
#
# Let's implement the forward pass and cross-entropy loss calculation given by the following equations.
#
# $$ \mathbf{h_t} = \tanh({W_{xh}\mathbf{x_t} + W_{hh}\mathbf{h_{t-1}}}) $$
#
# $$ \mathbf{p_t} = softmax(W_{hy}\mathbf{h_t}) $$
#
# $$ L = - \sum y_n\log(p_n) $$
#
# Here, $ \mathbf{x_t} $ is the 1-of-k encoded input at time $ t $, $ \mathbf{h_t} $ is the hidden state at time $ t $ and $ \mathbf{p_t} $ is the output character probabilities at time $ t $.

# %%
def forward(self, inputs, targets, hprev):
    xs = {} # 1-of-k encoded input
    hs = {} # Hidden state
    hs[-1] = np.copy(hprev)
    ys = {} # Unnormalized log probabilities for next characters
    ps = {} # Probabilities of next characters
    loss = 0
    data_size1, data_size2 = len(data), len(chars)

    
    # Iterate through every character in input, and
    # calculate xs, hs, ys, ps and cross-entropy loss
    # TODO
    for t in xrange(len(inputs)):
        xs[t] = np.zeros((data_size2,1)) 
        xs[t][inputs[t]] = 1 
        hs[t] = np.tanh(np.dot(self.W_xh, xs[t]) + np.dot(self.W_hh, hs[t-1]) + self.b_hh) 
        ys[t] = np.dot(self.W_hy, hs[t]) + self.b_hy 
        ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) 
        loss += -np.log(ps[t][targets[t],0]) 
        
    # END OF YOUR CODE
    
    return xs, hs, ps, loss

RNN.forward = forward

# %% [markdown]
# To check if our implementation is correct, we can compare the actual loss with expected loss for random predictions. If we initialize with equal weights, actual and expected loss would be exactly equal.

# %%
seq_length = 25

inputs = [char_to_ix[ch] for ch in data[0:seq_length]]
targets = [char_to_ix[ch] for ch in data[1:seq_length+1]]

r = RNN(len(chars))

loss_expected = -np.log(1.0/r.input_size) * seq_length
_, _, _, loss_actual = r.forward(inputs, targets, np.zeros((r.hidden_size, 1)))

print "Expected loss for random predictions: %f" % loss_expected
print "Actual loss: %f" % loss_actual
# Out:
# Expected loss for random predictions: 115.378013
# Actual loss: 115.370032

# %% [markdown]
# ## Backward Pass
#
# Next, we implement the backward pass. This is just application of the chain rule. One thing to keep in mind is that since RNN parameters are shared across time, gradient at each output depends not only on the current time step, but also the previous time steps.

# %%
def backward(self, input, targets, xs, hs, ps):
    gW_xh, gW_hh, gW_hy = np.zeros_like(self.W_xh), np.zeros_like(self.W_hh), np.zeros_like(self.W_hy)
    gb_hh, gb_hy = np.zeros_like(self.b_hh), np.zeros_like(self.b_hy)
    dhnext = np.zeros_like(hs[0])

    
    # Iterate through every character in reversed input, and
    # write backpropagation step
    # TODO
    for t in reversed(xrange(len(inputs))):
        dy = np.copy(ps[t])
        dy[targets[t]] -= 1 
        gW_hy += np.dot(dy, hs[t].T)
        gb_hy += dy
        dh = np.dot(self.W_hy.T, dy) + dhnext 
        gb_hh += (1 - hs[t] * hs[t]) * dh
        gW_xh += np.dot(((1 - hs[t] * hs[t]) * dh), xs[t].T)
        gW_hh += np.dot(((1 - hs[t] * hs[t]) * dh), hs[t-1].T)
        dhnext = np.dot(self.W_hh.T, ((1 - hs[t] * hs[t]) * dh))
    for dparam in [gW_xh, gW_hh, gW_hy, gb_hh, gb_hy]:
        np.clip(dparam, -5, 5, out=dparam) 
    # END OF YOUR CODE
    
    # Clipping gradients
    for gparam in [gW_xh, gW_hh, gW_hy, gb_hh, gb_hy]:
        np.clip(gparam, -5, 5, out = gparam)

    return gW_xh, gW_hh, gW_hy, gb_hh, gb_hy

RNN.backward = backward

# %% [markdown]
# It's always a good idea to compare the analytic and numerical gradients to check if our backpropagation is implemented correctly.

# %%
seq_length = 25

inputs = [char_to_ix[ch] for ch in data[0:seq_length]]
targets = [char_to_ix[ch] for ch in data[1:seq_length+1]]

r = RNN(len(chars))

delta = 1e-5

xs, hs, ps, loss_1 = r.forward(inputs, targets, np.zeros((r.hidden_size, 1)))
gW_xh, gW_hh, gW_hy, gb_hh, gb_hy = r.backward(inputs, targets, xs, hs, ps)
hprev = hs[len(inputs)-1]

for param, gparam in zip([r.W_xh, r.W_hh, r.W_hy, r.b_hh, r.b_hy],
                         [gW_xh, gW_hh, gW_hy, gb_hh, gb_hy]):
    ix = np.random.randint(0, param.size)
    old_val = param.flat[ix]
    
    param.flat[ix] = old_val + delta
    xs, hs, ps, loss_1 = r.forward(inputs, targets, hprev)
    _, _, _, _, _ = r.backward(inputs, targets, xs, hs, ps)
    
    param.flat[ix] = old_val - delta
    xs, hs, ps, loss_2 = r.forward(inputs, targets, hprev)
    _, _, _, _, _ = r.backward(inputs, targets, xs, hs, ps)
    
    param.flat[ix] = old_val
    
    grad_analytic = gparam.flat[ix]
    grad_numerical = (loss_1 - loss_2) / (2 * delta)
    rel_error = abs(grad_analytic - grad_numerical) / abs(grad_numerical + grad_analytic)
    print '%f, %f => %e ' % (grad_numerical, grad_analytic, rel_error)
# Out:
# 0.000000, 0.000000 => nan
# 0.000561, 0.000607 => 3.961764e-02
# 0.000058, 0.000076 => 1.327905e-01
# -0.060813, -0.060813 => 3.648113e-07
# 0.247517, 0.247516 => 1.930603e-06
# C:\Users\Karo\Anaconda\lib\site-packages\IPython\kernel\__main__.py:31: RuntimeWarning: invalid value encountered in double_scalars

# %% [markdown]
# ## Sampling and Beam search
#
# Given the distribution of character probabilities at each time step, there are several methods to obtain a single character that gets fed back into the RNN as input at the next time step.
#
# 1. Taking the maximum at the current time step.
# 2. Sampling from the distribution given by the softmax.
# 3. Taking the top k and implementing beam search.
#
# Here, we provide a completed implementation of (2) to sample from the distribution. Fill in the missing code to implement beam search (3).
#
# Beam Search is a search algorithm similar to Breadth First Search (BFS). More details can be found [here](http://www.cs.cmu.edu/afs/cs.cmu.edu/academic/class/46927-f97/slides/Lec3/sld023.htm) and [here](https://www.youtube.com/watch?v=G_teUutyC3Y)

# %%
def sample(self, seed_ix, n, hprev):
    h = np.copy(hprev)
    x = np.zeros((self.input_size, 1))
    x[seed_ix] = 1
    ixes = []
    for i in xrange(n):
        h = np.tanh(np.dot(self.W_xh, x) + np.dot(self.W_hh, h) + self.b_hh)
        y = np.dot(self.W_hy, h) + self.b_hy
        p = np.exp(y) / np.sum(np.exp(y))
        ix = np.random.choice(range(self.input_size), p=p.ravel())
        x = np.zeros((self.input_size, 1))
        x[ix] = 1
        ixes.append(ix)
    return ixes

RNN.sample = sample

# %%
def beam_search(self, seed_ix, n, hprev, beam_size = 5):
    h = np.copy(hprev)
    beams = [(0.0, [], h)] # log probabilities, indices, hidden state
    x = np.zeros((self.input_size, 1))
    x[seed_ix] = 1
    while n:
        # Select the top k characters from the distribution,
        # and maintain a buffer of the respective hidden states
        # TODO
        
        beam_candidates = []
        for b in beams:
            ixprev = b[1][-1] if b[1] else 0
            if ixprev == 0 and b[1]:
                beam_candidates.append(b)
                continue
            h=b[2]
            x = np.zeros((self.input_size, 1))
            x[ixprev] = 1
            h_c=np.tanh(np.dot(self.W_xh, x) + np.dot(self.W_hh, h) + self.b_hh)
            y_c = np.ravel(np.dot(self.W_hy, h_c) + self.b_hy )
            out_c= np.exp(y_c) / np.sum(np.exp(y_c))
            top_indices = np.argsort(-np.log(1e-20+out_c)) 
            for i in xrange(beam_size):
                wordix = top_indices[i]
                beam_candidates.append((b[0] + out_c[wordix], b[1] + [wordix], h_c))

            
            beam_candidates.sort(reverse = True) 
            beams = beam_candidates[:beam_size] 
        
        # END OF YOUR CODE
        n -= 1
    samples = [b[1] for b in beams]
    return samples

RNN.beam_search = beam_search

# %% [markdown]
# ## Finally, we put them together!
#
# ### Data
#
# Input: A sequence of characters (indices correspoding to the characters in the vocabulary) sampled from the input text file of length `seq_length`
#
# Target: Input sequence shifted by 1 and sampled from input text ie. if input is `x[t]`, then target is `x[t+1]` where `t` is iterating over the characters in the input text file.
#
# The task is set as a classification task where given the index of the current character, the model learns to predict the index of the next character from the vocabulary.
#
# ### Model
#
# As we are using a 1-hot representation of the input, the input size of the RNN corresponds to the size of the vocabulary. Increasing the hidden size increases the number of parameters to learn.
#
# ### Training
#
# In the *train* method. We use the [**AdaGrad**](http://cs231n.github.io/neural-networks-3/#ada) update to tweak our parameters. Typically, [perplexity](https://web.stanford.edu/class/cs124/lec/languagemodeling.pdf) is used as a measure the capability of the model to correctly predict the next sample. In this version only the softmax loss is calculated and used to decide the 'better' model.

# %%
def train(self, data, learning_rate = 1e-1, seq_length = 25):
    n = 0
    p = 0
    mW_xh, mW_hh, mW_hy = np.zeros_like(self.W_xh), np.zeros_like(self.W_hh), np.zeros_like(self.W_hy)
    mb_hh, mb_hy = np.zeros_like(self.b_hh), np.zeros_like(self.b_hy)
    smooth_loss = -np.log(1.0/self.input_size)*seq_length
    while True:
        if p + seq_length >= len(data) or n == 0:
            hprev = np.zeros((self.hidden_size, 1))
            p = 0

        inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]
        targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]

        if n % 100 == 0:
            samples = self.beam_search(inputs[0], seq_length, hprev, 5)
            for sample_ix in samples:
                txt = ''.join(ix_to_char[ix] for ix in sample_ix)
                print '----\n %s \n----' % (txt)

        xs, hs, ps, loss = self.forward(inputs, targets, hprev)
        gW_xh, gW_hh, gW_hy, gb_hh, gb_hy = self.backward(inputs, targets, xs, hs, ps)

        hprev = hs[len(inputs)-1]

        smooth_loss = smooth_loss * 0.999 + loss * 0.001
        if n % 100 == 0: print 'iter %d, loss: %f' % (n, smooth_loss)

        for param, gparam, mem in zip([self.W_xh, self.W_hh, self.W_hy, self.b_hh, self.b_hy],
                            [gW_xh, gW_hh, gW_hy, gb_hh, gb_hy],
                            [mW_xh, mW_hh, mW_hy, mb_hh, mb_hy]):
            mem += gparam * gparam
            param += -learning_rate * gparam / np.sqrt(mem + 1e-8) # adagrad update

        p += seq_length
        n += 1

RNN.train = train

# %%
r = RNN(len(chars), 200)
r.train(data, learning_rate = 1e-2, seq_length = 25)
# Out:
# ----
#  A`QY|(X%e9&J3h'h'h'h'h'hD
# ----
# ----
#  A`QY|(X%e9&J3h'h'h'h'h'h'
# ----
# ----
#  A`QY|(X%e9&J3h'h'h'h'h'hO
# ----
# ----
#  A`QY|(X%e9&J3h'h'h'h'h'hc
# ----
# ----
#  A`QY|(X%e9&J3h'h'h'h'h'h�
# ----
# iter 0, loss: 115.378009
# ----
#
# ----
# ----
#
#
# ----
# ----
#
# ----
# ----
#
#
# ----
# ----
#  																								i
# ----
# iter 100, loss: 113.326245
# ----
#  e
# ----
# ----
#  t
# ----
# ----
#  i
# ----
# ----
#  r
# ----
# ----
#
# ----
# iter 200, loss: 110.680373
# ----
#  idededededededededededede
# ----
# ----
#  idededededededededededene
# ----
# ----
#  idededededededededededed
# ----
# ----
#  idededededededededededen
# ----
# ----
#  idedededededededededededi
# ----
# iter 300, loss: 108.567583
# ----
#  rc__ce_ce_cc_rc__ce_ce_re
# ----
# ----
#  rc__ce_ce_cc_rc__ce_ce_rc
# ----
# ----
#  rc__ce_ce_cc_rc__ce_ce_ce
# ----
# ----
#  rc__ce_ce_cc_rc__ce_ce_cc
# ----
# ----
#  rc__ce_ce_cc_rc__rc__ce_c
# ----
# iter 400, loss: 106.477086
# ----
#  ine_ree
# ----
# ----
#  ineetee
# ----
# ----
#  ine_re
# ----
# ----
#  ineetel
# ----
# ----
#  ineete
# ----
# iter 500, loss: 103.947186
# ----
#  tecu_tecu_rcu_tecu_tecu_r
# ----
# ----
#  tecu_tecu_rcu_tecu_tecu_
# ----
# ----
#  tecu_tecu_rcu_tecu_tecu_e
# ----
# ----
#  tecu_tecu_rcu_tecu_tecu_o
# ----
# ----
#  tecu_tecu_rcu_tecu_rcu_te
# ----
# iter 600, loss: 101.697919
# ----
#  rcu_rcu_rcu_rcu_rcu_rcu_r
# ----
# ----
#  rcu_rcu_rcu_rcu_rcu_rcu_s
# ----
# ----
#  rcu_rcu_rcu_rcu_rcu_rcu_c
# ----
# ----
#  rcu_rcu_rcu_rcu_rcu_rcu_l
# ----
# ----
#  rcu_rcu_rcu_rcu_rcu_rcu_t
# ----
# iter 700, loss: 99.810325
# ----
#  ack_rcu_reatestack_rcu_te
# ----
# ----
#  ack_rcu_reatestack_rcu_re
# ----
# ----
#  ack_rcu_reatestack_rcu_se
# ----
# ----
#  ack_rcu_reatestack_rcu_ra
# ----
# ----
#  ack_rcu_reatestack_rcu_s
# ----
# iter 800, loss: 97.613876
# ----
#  _hestires_res
# ----
# ----
#  _hestintire
# ----
# ----
#  _hestires_*
# ----
# ----
#  _hestires_re
# ----
# ----
#  _hestintires
# ----
# iter 900, loss: 95.353236
# ----
#  inestires
# ----
# ----
#  inestines
# ----
# ----
#  inestiree
# ----
# ----
#  inestire
# ----
# ----
#  inestine
# ----
# iter 1000, loss: 93.403964
# ----
#  testertestinestisestires
# ----
# ----
#  testertestinestisestises
# ----
# ----
#  testertestinestisestirest
# ----
# ----
#  testertestinestisestire
# ----
# ----
#  testertestinestisestisest
# ----
# iter 1100, loss: 91.131993
# ----
#  rcu_terc__test_test_rcu_t
# ----
# ----
#  rcu_terc__test_test_rcu_r
# ----
# ----
#  rcu_terc__test_test_rcu_c
# ----
# ----
#  rcu_terc__test_test_rcu__
# ----
# ----
#  rcu_terc__test_test_rcu_s
# ----
# iter 1200, loss: 89.066579
# ----
#  _rentintentententintente
# ----
# ----
#  _rentintentententintenten
# ----
# ----
#  _rentintententententente
# ----
# ----
#  _rentintentententintenter
# ----
# ----
#  _rentintentententintenteo
# ----
# iter 1300, loss: 87.966395
# ----
#  ind__tack_;
#
# 		icu_te
#
# ----
# ----
#  ind__tack_;
#
# 		icu_te
#
#
# ----
# ----
#  ind__tack_;
#
# 		icu_te
#
# ----
# ----
#  ind__tack_;
#
# 		icu_te
# 		/
# ----
# ----
#  ind__tack_;
#
# 		icu_te
# 		r
# ----
# iter 1400, loss: 86.827883
# ----
#  *
#
#
#
#
#
#
#
# ----
# ----
#  *
#
#
#
#
#
#
#
# ----
# ----
#  *
#
#
#
#
#
#
# ----
# ----
#  *
#
#
#
#
#
#
# ----
# ----
#  *
#
#
#
#
#
#
#
# ----
# iter 1500, loss: 85.771802
# ----
#  incuutercuutercuutercuute
# ----
# ----
#  incuutercuutercuutercuude
# ----
# ----
#  incuutercuutercuutercu_te
# ----
# ----
#  incuutercuutercuutercuune
# ----
# ----
#  incuutercuutercuutercunte
# ----
# iter 1600, loss: 84.690305
# ----
#  tesesteseseresereteres_re
# ----
# ----
#  tesesteseseresereteresere
# ----
# ----
#  tesesteseseresereteresese
# ----
# ----
#  tesestesesereseretereses
# ----
# ----
#  tesesteseseresereteresest
# ----
# iter 1700, loss: 83.522415
# ----
#  intesestack_tack_tack_tas
# ----
# ----
#  intesestack_tack_tack_tac
# ----
# ----
#  intesestack_tack_tack_tag
# ----
# ----
#  intesestack_tack_tack_tad
# ----
# ----
#  intesestack_tack_tack_tat
# ----
# iter 1800, loss: 82.351394
# ----
#  toresertererentererentere
# ----
# ----
#  toresertererentererentese
# ----
# ----
#  toresertererentererentes
# ----
# ----
#  toresertererentererentest
# ----
# ----
#  toresertererentererentern
# ----
# iter 1900, loss: 81.039475
# ----
#  tack_;
#
#
#
#
#
#
#
#
#
#
#
# ----
# ----
#  tack_;
#
#
#
#
#
#
#
#
#
#
# ----
# ----
#  tack_;
#
#
#
#
#
#
#
#
#
#
#
# ----
# ----
#  tack_;
#
#
#
#
#
#
#
#
#
#
# ----
# ----
#  tack_;
#
#
#
#
#
#
#
#
#
#
#
#
# ----
# iter 2000, loss: 79.969120
# ----
#  oree_tore_tore_tore_tore_
# ----
# ----
#  oree_tore_tore_tore_tore
# ----
# ----
#  oree_tore_tore_tore_tare_
# ----
# ----
#  oree_tore_tore_tore_tare
# ----
# ----
#  oree_tore_tore_tore_toree
# ----
# iter 2100, loss: 78.837663
# ----
#  {
# 		int_rete_tere_tore_te
# ----
# ----
#  {
# 		int_rete_tere_tore_to
# ----
# ----
#  {
# 		int_rete_tere_tore_en
# ----
# ----
#  {
# 		int_rete_tere_tore_me
# ----
# ----
#  {
# 		int_rete_tere_tore_ta
# ----
# iter 2200, loss: 77.711154
# ----
#  L_SEEEEEEEEEEEEEEEEEEEEEE
# ----
# ----
#  L_SELEEEEEEEEEEEEEEEEEEEE
# ----
# ----
#  L_EEEEEEEEEEEEEEEEEEEEEEE
# ----
# ----
#  L_SEEEEEEEEEEEEEEEEEEEEEL
# ----
# ----
#  L_SEEEEEEEEEEEEEEEEEEEELE
# ----
# iter 2300, loss: 76.920925
# ----
#  interererererererererere
# ----
# ----
#  intererererererererererer
# ----
# ----
#  interererererererereret
# ----
# ----
#  intererererererererereree
# ----
# ----
#  intererererererererereret
# ----
# iter 2400, loss: 75.897811
# ----
#  torerererererererererere
# ----
# ----
#  torerererererererererent
# ----
# ----
#  torererererererererererer
# ----
# ----
#  torererererererererereres
# ----
# ----
#  torererererererererereren
# ----
# iter 2500, loss: 75.184772
# ----
#  more_pane_pone_pone_pone_
# ----
# ----
#  more_pane_pone_pone_pone
# ----
# ----
#  more_pane_pone_pone_pane_
# ----
# ----
#  more_pane_pone_pane_pane_
# ----
# ----
#  mare_pane_pone_pane_pane_
# ----
# iter 2600, loss: 74.437781
# ----
#  e_mage_tage_page_page_pag
# ----
# ----
#  e_mage_page_page_page_pag
# ----
# ----
#  e_page_page_page_page_pag
# ----
# ----
#  e_mage_tage_page_page_bag
# ----
# ----
#  e_mage_tage_page_page_pan
# ----
# iter 2700, loss: 73.792061
# ----
#  *
#
# 		stage_page_page_page
# ----
# ----
#  *
#
# 		stage_page_tage_page
# ----
# ----
#  *
#
# 		stage_page_page_tage
# ----
# ----
#  *
#
# 		stage_page_page_pane
# ----
# ----
#  *
#
# 		stage_page_page_pone
# ----
# iter 2800, loss: 72.775861
# ----
#  page_page_page_page_page
# ----
# ----
#  page_page_page_page_pages
# ----
# ----
#  page_page_page_page_page_
# ----
# ----
#  page_page_page_page_pane
# ----
# ----
#  page_page_page_page_pager
# ----
# iter 2900, loss: 71.880898
# ----
#  *
#
#
# 		stage_page_page_pag
# ----
# ----
#  *
#
#
# 		stare_page_page_pag
# ----
# ----
#  *
#
#
# 		stage_page_page_pon
# ----
# ----
#  *
#
#
# 		stage_page_page_pan
# ----
# ----
#  *
#
#
# 		stare_page_page_pan
# ----
# iter 3000, loss: 71.096628
# ----
#  lore_page_page_page_page
# ----
# ----
#  lore_page_page_page_page_
# ----
# ----
#  lore_page_page_page_pages
# ----
# ----
#  lore_page_page_page_pagee
# ----
# ----
#  lore_page_page_page_pager
# ----
# iter 3100, loss: 70.268972
# ----
#  mage_page_page_page_page
# ----
# ----
#  page_page_page_page_page
# ----
# ----
#  mage_page_page_page_page_
# ----
# ----
#  page_page_page_page_page_
# ----
# ----
#  mage_page_page_page_pages
# ----
# iter 3200, loss: 69.900389
# ----
#  ionesimememagesememages
# ----
# ----
#  ionesimememagesememaget
# ----
# ----
#  ionesimememagesememage
# ----
# ----
#  ionesimememagesememageses
# ----
# ----
#  ionesimememagesememagesem
# ----
# iter 3300, loss: 69.179414
# ----
#  NEEEEEE;
# 		ree_page_pages
# ----
# ----
#  NEEEEEE;
# 		ree_page_page_
# ----
# ----
#  NEEEEEE;
# 		ree_page_page
# ----
# ----
#  NEEEEEE;
# 		ree_page_pagem
# ----
# ----
#  NEEEEEE;
# 		ree_page_paget
# ----
# iter 3400, loss: 68.389951
# ----
#  mage_page_page_page_pages
# ----
# ----
#  mage_page_page_page_page_
# ----
# ----
#  mage_page_page_page_pagem
# ----
# ----
#  mage_page_page_page_page
# ----
# ----
#  mage_page_page_page_paget
# ----
# iter 3500, loss: 67.586877
# ----
#  lone_page_page);
# 	/*
#
#
#
# ----
# ----
#  lone_page_page);
# 	/*
#
#
# ----
# ----
#  lone_page_page);
# 	/*
#
# 		i
# ----
# ----
#  lone_page_page);
# 	/*
#
# 		r
# ----
# ----
#  lone_page_page);
# 	/*
#
# 		*
# ----
# iter 3600, loss: 67.674283
# ----
#  {
#
# ----
# ----
#  {
# 																				re
# ----
# ----
#  {
#
# ----
# ----
#  {
# 																					re
# ----
# ----
#  {
# 																						r
# ----
# iter 3700, loss: 67.157166
# ----
#  tagestanes
# ----
# ----
#  tagestates
# ----
# ----
#  tagestane
# ----
# ----
#  tagestate
# ----
# ----
#  tagestree
# ----
# iter 3800, loss: 66.645632
# ----
#  the_page_page_page_pages
# ----
# ----
#  the_page_page_page_paget
# ----
# ----
#  the_page_page_page_page_p
# ----
# ----
#  the_page_page_page_page
# ----
# ----
#  the_page_page_page_pagest
# ----
# iter 3900, loss: 65.765710
# ----
#  page_page_page_page_page
# ----
# ----
#  page_page_page_page_page_
# ----
# ----
#  page_page_page_page_pages
# ----
# ----
#  page_page_page_page_pagem
# ----
# ----
#  page_page_page_page_page(
# ----
# iter 4000, loss: 64.885401
# ----
#  hage_page_page_page_pages
# ----
# ----
#  hage_page_page_page_page_
# ----
# ----
#  hage_page_page_page_page
# ----
# ----
#  hage_page_page_page_paget
# ----
# ----
#  hage_page_page_page_page(
# ----
# iter 4100, loss: 64.363920
# ----
#  hestree
# ----
# ----
#  hestrer
# ----
# ----
#  hestrem
# ----
# ----
#  hestrec
# ----
# ----
#  hestre
# ----
# iter 4200, loss: 63.927810
# ----
#  hagereadererereredered
# ----
# ----
#  hagereaderererereded
# ----
# ----
#  hagereaderererered
# ----
# ----
#  hagereadererereredere
# ----
# ----
#  hagereaderererereder
# ----
# iter 4300, loss: 63.773942
# ----
#  */
# 	restreestreestrrestre
# ----
# ----
#  */
# 	restreestreestrrestin
# ----
# ----
#  */
# 	restreestreestrrestor
# ----
# ----
#  */
# 	restreestreestrreston
# ----
# ----
#  */
# 	restreestreestrrestrr
# ----
# iter 4400, loss: 64.346097
# ----
#  intereestrrestorestrrestr
# ----
# ----
#  intereestrrestorestrresto
# ----
# ----
#  intereestrrestorestrreste
# ----
# ----
#  intereestrrestorestrresta
# ----
# ----
#  intereestrrestorestrresti
# ----
# iter 4500, loss: 64.061628
# ----
#  torestarestarestarestate
# ----
# ----
#  torestarestarestarestare
# ----
# ----
#  torestarestarestarestore
# ----
# ----
#  torestarestarestarestares
# ----
# ----
#  torestarestarestarestaret
# ----
# iter 4600, loss: 63.999835
# ----
#  torestrecterestorestate
# ----
# ----
#  torestrecterestorestoree
# ----
# ----
#  torestrecterestorestores
# ----
# ----
#  torestrecterestorestorest
# ----
# ----
#  torestrecterestorestore
# ----
# iter 4700, loss: 63.535566
# ----
#  freezer);
# {
# 	reezereezer
# ----
# ----
#  freezer);
# {
# 	reezereezere
# ----
# ----
#  freezer);
# 		reezereezeree
# ----
# ----
#  freezer);
# {
# 	reezereezer_
# ----
# ----
#  freezer);
# 		reezereezer);
# ----
# iter 4800, loss: 62.953239
# ----
#  U
# ----
# ----
#  P
# ----
# ----
#  F
# ----
# ----
#  R
# ----
# ----
#  N
# ----
# iter 4900, loss: 63.868549
# ----
#  CUL_CUU__CUU_RUU_RUU_RUU_
# ----
# ----
#  CUL_CUU__CUU_RUU_RUU_CUU_
# ----
# ----
#  CUL_CUU__CUU_RUU_RUU_NUU_
# ----
# ----
#  CUL_CUU__CUU_RUU_RUU__CUU
# ----
# ----
#  CUL_CUU__CUU_RUU_RUU__CU_
# ----
# iter 5000, loss: 64.552155
# ----
#  */
#
# ----
# ----
#  */
#
# ----
# ----
#  */
# 																				/*
# ----
# ----
#  */
# 																			/*
# ----
# ----
#  */
# 																					/
# ----
# iter 5100, loss: 64.476283
# ----
#  torestoree
# ----
# ----
#  torestine
# ----
# ----
#  torestint
# ----
# ----
#  torestore
# ----
# ----
#  torestone
# ----
# iter 5200, loss: 64.218849
# ----
#  thet
# ----
# ----
#  thes
# ----
# ----
#  tore
# ----
# ----
#  ther
# ----
# ----
#  the
# ----
# iter 5300, loss: 64.578913
# ----
#  lock_page_pack_pack_page
# ----
# ----
#  lock_page_pack_pack_pack_
# ----
# ----
#  lock_page_pack_pack_pack
# ----
# ----
#  lock_page_pack_pack_page_
# ----
# ----
#  lock_page_pack_pack_pages
# ----
# iter 5400, loss: 64.832712
# ----
#  theedereedereedereederee
# ----
# ----
#  theedereedereedereedereed
# ----
# ----
#  theedereedereedereederere
# ----
# ----
#  theedereedereedereederees
# ----
# ----
#  theedereedereedereederee_
# ----
# iter 5500, loss: 64.966431
# ----
#  */
# 		/*/
# 			/*/
# 			/*/
#
# ----
# ----
#  */
# 		/*/
# 			/*/
# 			/*/
# /*
# ----
# ----
#  */
# 		/*/
# 			/*/
# /*/
# /*/
#
# ----
# ----
#  */
# 		/*/
# 			/*/
# 			/*/
# 	s
# ----
# ----
#  */
# 		/*/
# 			/*/
# 			/*/
# 	r
# ----
# iter 5600, loss: 64.888548
# ----
#  tauctares_state
# ----
# ----
#  tauctares_stare
# ----
# ----
#  tauctares_stact
# ----
# ----
#  tauctares_stade
# ----
# ----
#  tauctares_stast
# ----
# iter 5700, loss: 64.546114
# ----
#  cu_struct_rcu_stack;
# 	st
# ----
# ----
#  cu_struct_rcu_stack;
# 	sta
# ----
# ----
#  cu_struct_rcu_stack;
# /*
#
# ----
# ----
#  cu_struct_rcu_stack;
# /*/
#
# ----
# ----
#  cu_struct_rcu_stack;
# 	str
# ----
# iter 5800, loss: 64.049838
# ----
#  nondericu_pages_statind
# ----
# ----
#  nondericu_pages_staticu_n
# ----
# ----
#  nondericu_pages_staticurn
# ----
# ----
#  nondericu_pages_statin
# ----
# ----
#  nondericu_pages_staticu_p
# ----
# iter 5900, loss: 64.215458
# ----
#  */
# /*
# #intireedereededed
# ----
# ----
#  */
# /*
# #intireedereederee
# ----
# ----
#  */
# /*
# #intireedereedereed
# ----
# ----
#  */
# /*
# #intireedereededere
# ----
# ----
#  */
# /*
# #intireedereederee_
# ----
# iter 6000, loss: 64.558728
# ----
#  locu_tack_pagestructaree
# ----
# ----
#  locu_tack_pagestructeree
# ----
# ----
#  locu_tack_pagestructare
# ----
# ----
#  locu_tack_pagestructareed
# ----
# ----
#  locu_tack_pagestructereed
# ----
# iter 6100, loss: 65.007025
# ----
#  lonterinterintarestrrestr
# ----
# ----
#  lonterinterintarestrresta
# ----
# ----
#  lonterinterintarestrret
# ----
# ----
#  lonterinterintarestrresti
# ----
# ----
#  lonterinterintarestrrest
# ----
# iter 6200, loss: 65.021510
# ----
#  the
#
# ----
# ----
#  ther
# ----
# ----
#  fore
# ----
# ----
#  then
# ----
# ----
#  the
# ----
# iter 6300, loss: 64.761898
# ----
#  the
#
# ----
# ----
#  thes
# ----
# ----
#  ther
# ----
# ----
#  the
# ----
# ----
#  then
# ----
# iter 6400, loss: 65.191765
# ----
#  *
#
# 		retirned_restarestar
# ----
# ----
#  *
#
# 		retirned_restarestat
# ----
# ----
#  *
#
# 		retirned_pagestares
# ----
# ----
#  *
#
# 		retirned_pagestarest
# ----
# ----
#  *
#
# 		retirned_restarestan
# ----
# iter 6500, loss: 65.494343
# ----
#  lock_page_pagestare;
# {
#
# ----
# ----
#  lock_page_pagestare;
#
# ----
# ----
#  lock_page_pagestare;
# 			r
# ----
# ----
#  lock_page_pagestare;
#
#
# ----
# ----
#  lock_page_pagestare;
# 			s
# ----
# iter 6600, loss: 65.404089
# ----
#  intertestructerestructere
# ----
# ----
#  intertestructerestructert
# ----
# ----
#  intertestructerestruct_re
# ----
# ----
#  intertestructerestructerc
# ----
# ----
#  intertestructertestruct
# ----
# iter 6700, loss: 65.427638
# ----
#  thuchintindexdinex.
# 	/*
# #
# ----
# ----
#  thuchintindexdinex.
# 	/*
#
# ----
# ----
#  thuchintindexdinex.
# 	/*
#
#
# ----
# ----
#  thuchintindexdinex.
# 		/*
#
# ----
# ----
#  thuchintindexdinex.
# 	{
#
# ----
# iter 6800, loss: 65.425331
# ----
#  lock_pages_structereeder
# ----
# ----
#  lock_pages_structereedere
# ----
# ----
#  lock_pages_structereedes
# ----
# ----
#  lock_pages_structereederi
# ----
# ----
#  lock_pages_structereeder_
# ----
# iter 6900, loss: 65.522223
# ----
#  statis
# ----
# ----
#  states
# ----
# ----
#  statin
# ----
# ----
#  state
# ----
# ----
#  statk
# ----
# iter 7000, loss: 65.768070
# ----
#  stask_task);
# }
#
# statit
# ----
# ----
#  stask_task);
# }
#
# statis
# ----
# ----
#  stask_task);
# }
#
# statin
# ----
# ----
#  stask_task);
# }
#
# state
# ----
# ----
#  stask_task);
# }
#
# statk
# ----
# iter 7100, loss: 65.552326
# ----
#  ing_stack);
# 	}
#
# 	restint
# ----
# ----
#  ing_stack);
# 	}
#
# 	restruct
# ----
# ----
#  ing_stack);
# 	}
#
# 	resting
# ----
# ----
#  ing_stack);
# 	}
#
# 	restine
# ----
# ----
#  ing_stack);
# 	}
#
# 	restinge
# ----
# iter 7200, loss: 65.433949
# ----
#  intistask_stack);
# }
#
# 	in
# ----
# ----
#  intistask_stack);
# }
#
# stat
# ----
# ----
#  intistask_stack);
# }
#
# stru
# ----
# ----
#  intistask_stack);
# }
#
# 	int
# ----
# ----
#  intistask_stack);
# }
#
# stas
# ----
# iter 7300, loss: 65.062602
# ----
#  ingestare_signer_sighesta
# ----
# ----
#  ingestare_signer_sigher
# ----
# ----
#  ingestare_signer_sighestr
# ----
# ----
#  ingestare_signer_sighes
# ----
# ----
#  ingestare_signer_sighest
# ----
# iter 7400, loss: 64.599313
# ----
#  {
# 		/*/
# 	statit
# ----
# ----
#  {
# 		/*/
# 	statis
# ----
# ----
#  {
# 		/*/
# 	statin
# ----
# ----
#  {
# 		/*/
# 	intinn
# ----
# ----
#  {
# 		/*/
# 	state
# ----
# iter 7500, loss: 64.309117
# ----
#  ingestarestatistatinned
# ----
# ----
#  ingestarestatistatinnedin
# ----
# ----
#  ingestarestatistatind
# ----
# ----
#  ingestarestatistatinnedit
# ----
# ----
#  ingestarestatistatinnedig
# ----
# iter 7600, loss: 64.110598
# ----
#  lont
# ----
# ----
#  lone
# ----
# ----
#  lock
# ----
# ----
#  lore
# ----
# ----
#  the
# ----
# iter 7700, loss: 63.765132
# ----
#  thestint
# ----
# ----
#  thesting
# ----
# ----
#  thestine
# ----
# ----
#  thestinn
# ----
# ----
#  thestask
# ----
# iter 7800, loss: 63.123628
# ----
#  the_signed_signed_signed_
# ----
# ----
#  the_signed_signed_signal_
# ----
# ----
#  the_signed_signed_signel_
# ----
# ----
#  the_signed_signed_signed
# ----
# ----
#  the_signed_signed_signale
# ----
# iter 7900, loss: 63.108703
# ----
#  ing
# ----
# ----
#  =
# ----
# ----
#  he
# ----
# ----
#  *
# ----
# ----
#  inge
# ----
# iter 8000, loss: 62.894509
# ----
#  the
# ----
# ----
#  ind
# ----
# ----
#  =
# ----
# ----
#  in
# ----
# ----
#  *
# ----
# iter 8100, loss: 62.321567
# ----
#  SINL);
# 		returned_siglock
# ----
# ----
#  SINL);
# 		returned_sighend
# ----
# ----
#  SINL);
# 		returned_siglond
# ----
# ----
#  SINL);
# 		returned_sigher
# ----
# ----
#  SINL);
# 		returned_siglonk
# ----
# iter 8200, loss: 61.940993
# ----
#  thack_sig);
# }
#
# 	retuct
# ----
# ----
#  thack_sig);
# }
#
# 	retust
# ----
# ----
#  thack_sig);
# }
#
# 	reture
# ----
# ----
#  thack_sig);
# }
#
# 	returnt
# ----
# ----
#  thack_sig);
# }
#
# 	return
# ----
# iter 8300, loss: 61.570795
# ----
#  signal_siglock_signal_sig
# ----
# ----
#  signal_siglock_signallock
# ----
# ----
#  signal_siglock_signal_sin
# ----
# ----
#  signal_siglock_signallont
# ----
# ----
#  signal_siglock_signallond
# ----
# iter 8400, loss: 61.597407
# ----
#  *;
#
# 	reture
# ----
# ----
#  *;
#
# 	sighes
# ----
# ----
#  *;
#
# 	sigher
# ----
# ----
#  *;
#
# 	sighe
# ----
# ----
#  *;
#
# 	sighen
# ----
# iter 8500, loss: 61.890189
# ----
#  sighand_siglock);
# }
#
# 	if
# ----
# ----
#  sighand_siglock);
# }
#
# 	ret
# ----
# ----
#  sighand_siglock);
# }
#
# 	int
# ----
# ----
#  sighand_siglock);
# }
#
# 	re
# ----
# ----
#  sighand_siglock);
# }
#
# 	in
# ----
# iter 8600, loss: 61.876434
# ----
#  the
#
# ----
# ----
#  the
#
# ----
# ----
#  the
# 																		re
# ----
# ----
#  the
# 																			re
# ----
# ----
#  the
# 																				r
# ----
# iter 8700, loss: 61.621128
# ----
#  *
# 		/*
#
# ----
# ----
#  *
#
# ----
# ----
#  *
# 		/*
#
# ----
# ----
#  *
#
# ----
# ----
#  *
# 		/*
# 															re
# ----
# iter 8800, loss: 61.570777
# ----
#  CONTIG_SIGL_SIG_SIG_SIGL_
# ----
# ----
#  CONTIG_SIGL_SIGL_SIGL_SIG
# ----
# ----
#  CONTIG_SIGL_SIG_SIGL_SIG_
# ----
# ----
#  CONTIG_SIGL_SIGL_SIGL_SIN
# ----
# ----
#  CONTIG_SIGL_SIG_SIGL_SIGL
# ----
# iter 8900, loss: 61.395767
# ----
#  thack_siglock);
# 		/*
#
# ----
# ----
#  thack_siglock);
# 		/*/
#
# ----
# ----
#  thack_siglock);
# 		/*
#
# ----
# ----
#  thack_siglock);
# 		/*
# 		/*
# ----
# ----
#  thack_siglock);
# 		/*
#
#
# ----
# iter 9000, loss: 60.953416
# ----
#  forestruct_pignon_sigher
# ----
# ----
#  forestruct_pignon_signon
# ----
# ----
#  forestruct_pignon_sighen
# ----
# ----
#  forestruct_pignon_sighe
# ----
# ----
#  forestruct_pignon_signal_
# ----
# iter 9100, loss: 60.726190
# ----
#  horererestruct_pignal);
#
# ----
# ----
#  horererestruct_pignal();
#
# ----
# ----
#  horererestruct_pignal);
#
#
# ----
# ----
#  horererestruct_pignal);{
#
# ----
# ----
#  horererestruct_pignal);
# }
# ----
# iter 9200, loss: 60.361427
# ----
#  signal_signal();
# 		/*
#
# ----
# ----
#  signal_signal();
# 		/*/
#
# ----
# ----
#  signal_signal();
# 		/*
#
#
# ----
# ----
#  signal_signal();
# 		/*
#
# ----
# ----
#  signal_signal();
# 		/*
# 		i
# ----
# iter 9300, loss: 59.818789
# ----
#  signal_signal_signal_sign
# ----
# ----
#  signal_signal_signal_sigh
# ----
# ----
#  signal_signal_signal_sigl
# ----
# ----
#  signal_signal_signal_sige
# ----
# ----
#  signal_signal_signal_sig_
# ----
# iter 9400, loss: 59.553887
# ----
#  signaldestask_signal_sign
# ----
# ----
#  signaldestask_signal_sigl
# ----
# ----
#  signaldestask_signal_sigs
# ----
# ----
#  signaldestask_signal_sigh
# ----
# ----
#  signaldestask_signal_sige
# ----
# iter 9500, loss: 59.452329
# ----
#  signal_signal_signal_sign
# ----
# ----
#  signal_signal_sighend_sig
# ----
# ----
#  signal_signal_signal_sigs
# ----
# ----
#  signal_signal_signal_sigl
# ----
# ----
#  signal_signal_signal_sigh
# ----
# iter 9600, loss: 59.429462
# ----
#  forest_sigrest_signal_sig
# ----
# ----
#  forest_sigrest_sigse_sign
# ----
# ----
#  forest_sigrest_sigser_sig
# ----
# ----
#  forest_sigrest_sigse_sig_
# ----
# ----
#  forest_sigrest_sigse_sigs
# ----
# iter 9700, loss: 59.810525
# ----
#  signal_siglock->siglock->
# ----
# ----
#  signal_siglock->siglock_s
# ----
# ----
#  signal_siglock->siglock_t
# ----
# ----
#  signal_siglock->siglocked
# ----
# ----
#  signal_siglock->siglock_p
# ----
# iter 9800, loss: 59.757973
# ----
#  siglock);
# }
#
# 	returned);
#
# ----
# ----
#  siglock);
# }
#
# 	returned_si
# ----
# ----
#  siglock);
# }
#
# 	returned)
#
# ----
# ----
#  siglock);
# }
#
# 	returned)
# {
# ----
# ----
#  siglock);
# }
#
# 	returned_st
# ----
# iter 9900, loss: 59.556823
# ----
#  SIG_SILL);
# }
#
# /*/
# /*
#
# 	/*
# ----
# ----
#  SIG_SILL);
# }
#
# /*/
# /*
#
# 	in
# ----
# ----
#  SIG_SILL);
# }
#
# /*/
# /*
#
# 	re
# ----
# ----
#  SIG_SILL);
# }
#
# /*/
# /*
#
# 	if
# ----
# ----
#  SIG_SILL);
# }
#
# /*/
# /*
#
# 	si
# ----
# iter 10000, loss: 59.570310
# ----
#  signallock);
# 	}
#
# 	/*/
#
#
# ----
# ----
#  signallock);
# 	}
#
# 	/*/
# 	si
# ----
# ----
#  signallock);
# 	}
#
# 	/*/
# 	in
# ----
# ----
#  signallock);
# 	}
#
# 	/*/
#
# ----
# ----
#  signallock);
# 	}
#
# 	/*/
# 		i
# ----
# iter 10100, loss: 59.324887
# ----
#  ->sigse_sigse_sigse_sig,
# ----
# ----
#  ->sigse_sigse_sigse_signa
# ----
# ----
#  ->sigse_sigse_sigse_sigse
# ----
# ----
#  ->sigse_sigse_sigse_signo
# ----
# ----
#  ->sigse_sigse_sigse_signe
# ----
# iter 10200, loss: 59.496087
# ----
#  ->siglock);
# 	}
#
# 	/*
#
# 		se
# ----
# ----
#  ->siglock);
# 	}
#
# 	/*
#
#
# ----
# ----
#  ->siglock);
# 	}
#
# 	/*
#
# 		st
# ----
# ----
#  ->siglock);
# 	}
#
# 	/*
#
# 	int
# ----
# ----
#  ->siglock);
# 	}
#
# 	/*
#
# 			s
# ----
# iter 10300, loss: 59.575024
# ----
#  {
# 	}
#
# 	reture
# ----
# ----
#  {
# 	}
#
# 	return
# ----
# ----
#  {
# 	}
#
# 	retare
# ----
# ----
#  {
# 	}
#
# 	returne
# ----
# ----
#  {
# 	}
#
# 	retore
# ----
# iter 10400, loss: 59.525787
# ----
#  signal_sigpandingock_sigs
# ----
# ----
#  signal_sigpandingock_sign
# ----
# ----
#  signal_sigpandingock_sigp
# ----
# ----
#  signal_sigpandingock_sigd
# ----
# ----
#  signal_sigpandingock_sigl
# ----
# iter 10500, loss: 59.405684
# ----
#  sigse_sigset_sigsigsigsig
# ----
# ----
#  sigse_sigset_sigsigsigset
# ----
# ----
#  sigse_sigset_sigsigsignal
# ----
# ----
#  sigse_sigset_sigsigsigser
# ----
# ----
#  sigse_sigset_sigsigsigses
# ----
# iter 10600, loss: 59.292382
# ----
#  sighending
# 	returned_sign
# ----
# ----
#  sighending
# 	returned,
# 	}
#
# ----
# ----
#  sighending
# 	returned_sigs
# ----
# ----
#  sighending
# 	returned_sigh
# ----
# ----
#  sighending
# 	returned_sige
# ----
# iter 10700, loss: 60.411129
# ----
#  *
#
# ----
# ----
#  */
#
# ----
# ----
#  *
#
# ----
# ----
#  */
#
# ----
# ----
#  *
# 																						/
# ----
# iter 10800, loss: 61.502144
# ----
#  signaterrentrret);
# }
#
# 	re
# ----
# ----
#  signaterrentrret);
# 	int
# ----
# ----
#  signaterrentrret);
# 	signe
# ----
# ----
#  signaterrentrret);
# }
#
#
# ----
# ----
#  signaterrentrret);
# }
#
#
# ----
# iter 10900, loss: 61.741707
# ----
#  the
# 	{
# 		returner_calle);
# ----
# ----
#  the
# 	{
# 		returner_callet
# ----
# ----
#  the
# 	{
# 		returner_caller
# ----
# ----
#  the
# 	{
# 		returner_calle
# ----
# ----
#  the
# 	{
# 		returner_callere
# ----
# iter 11000, loss: 61.747927
# ----
#  thet
# ----
# ----
#  ther
# ----
# ----
#  thee
# ----
# ----
#  the
# ----
# ----
#  then
# ----
# iter 11100, loss: 61.637789
# ----
#  */
# 	returned_frect);
# 	ret
# ----
# ----
#  */
# 	returned_frect);
# 		re
# ----
# ----
#  */
# 	returned_frect);
# 	ift
# ----
# ----
#  */
# 	returned_frect);
# }
#
#
# ----
# ----
#  */
# 	returned_frect);
# 	if
# ----
# iter 11200, loss: 61.109062
# ----
#
# 	return
# 			return
# 			ret
# ----
# ----
#
# 	return
# 			return
# 		int
# ----
# ----
#
# 	return
# 			return
# 		retu
# ----
# ----
#
# 	return
# 			return
# 		ret
# ----
# ----
#
# 	return
# 			return
# 		ret_
# ----
# iter 11300, loss: 60.467286
# ----
#  frect->sigter_struct)
#
# ----
# ----
#  frect->sigter_struct->sig
# ----
# ----
#  frect->sigter_struct)
# 		r
# ----
# ----
#  frect->sigter_struct)
# 		i
# ----
# ----
#  frect->sigter_struct)
# 		s
# ----
# iter 11400, loss: 59.847094
# ----
#  fore_struct);
# }
#
# struct
# ----
# ----
#  fore_struct);
# }
#
# struct_p
# ----
# ----
#  fore_struct);
# }
#
# struct_f
# ----
# ----
#  fore_struct);
# }
#
# struct_r
# ----
# ----
#  fore_struct);
# }
#
# struct_s
# ----
# iter 11500, loss: 59.396405
# ----
#  sigser_pred);
# 	}
#
# }
#
# 	if
# ----
# ----
#  sigser_pred);
# 	}
#
# }
#
# 	int
# ----
# ----
#  sigser_pred);
# 	}
#
# 	return
# ----
# ----
#  sigser_pred);
# 	}
#
# }
#
# 	ift
# ----
# ----
#  sigser_pred);
# 	}
#
# 	reture
# ----
# iter 11600, loss: 59.038367
# ----
#  ter_paster_struct->sigser
# ----
# ----
#  ter_paster_struct->sigter
# ----
# ----
#  ter_paster_struct->sigset
# ----
# ----
#  ter_paster_struct->sigsel
# ----
# ----
#  ter_paster_struct->sigsed
# ----
# iter 11700, loss: 58.702715
# ----
#  */
#
# ----
# ----
#  */
#
# ----
# ----
#  */
# 																				re
# ----
# ----
#  */
# 																					i
# ----
# ----
#  */
# 																					r
# ----
# iter 11800, loss: 58.131854
# ----
#  therer_palder_palder_pint
# ----
# ----
#  therer_palder_palder_pald
# ----
# ----
#  therer_palder_palder_palt
# ----
# ----
#  therer_palder_palder_pall
# ----
# ----
#  therer_palder_pallerent_p
# ----
# iter 11900, loss: 57.766241
# ----
#  foret_pred->filter_pred->
# ----
# ----
#  foret_pred->filter_pred_p
# ----
# ----
#  foret_pred->filter_predtr
# ----
# ----
#  foret_pred->filter_pred_s
# ----
# ----
#  foret_pred->filter_pred_f
# ----
# iter 12000, loss: 57.449127
# ----
#  *pred);
# 	}
#
# 	returner);
#
# ----
# ----
#  *pred);
# 	}
#
# 	returner)
#
# ----
# ----
#  *pred);
# 	}
#
# 	returner)
# {
#
# ----
# ----
#  *pred);
# 	}
#
# 	returner);
# }
# ----
# ----
#  *pred);
# 	}
#
# 	returner);
#
#
# ----
# iter 12100, loss: 56.895342
# ----
#  struct)
# {
# 	struct_filter_
# ----
# ----
#  struct)
# {
# 	struct(filter_
# ----
# ----
#  struct)
# {
# 	struct_filter
# ----
# ----
#  struct)
# {
# 	struct_filler_
# ----
# ----
#  struct)
# {
# 	struct_filtere
# ----
# iter 12200, loss: 56.397304
# ----
#  filter);
# 	}
#
# 	struct_filt
# ----
# ----
#  filter);
# 	}
#
# 	struct_fist
# ----
# ----
#  filter);
# 	}
#
# 	struct_fint
# ----
# ----
#  filter);
# 	}
#
# 	struct_file
# ----
# ----
#  filter);
# 	}
#
# 	struct_fill
# ----
# iter 12300, loss: 55.920463
# ----
#  entrred_filter);
# 		struct
# ----
# ----
#  entrred_filter);
# }
#
# struc
# ----
# ----
#  entrred_filter);
# 		strunt
# ----
# ----
#  entrred_filter);
# 		struce
# ----
# ----
#  entrred_filter);
# 		struc
# ----
# iter 12400, loss: 55.387078
# ----
#  inter_filter);
# 	}
#
# 	struc
# ----
# ----
#  inter_filter);
# 	}
#
# }
#
# 	if
# ----
# ----
#  inter_filter);
# 	}
#
# }
#
# str
# ----
# ----
#  inter_filter);
# 	}
#
# }
#
# 	st
# ----
# ----
#  inter_filter);
# 	}
#
# }
#
# 	in
# ----
# iter 12500, loss: 54.777965
# ----
#  FILL_FILL_FILL_FILL_FILL_
# ----
# ----
#  FILL_FILL_FILL_FILL_FILE_
# ----
# ----
#  FILL_FILL_FILL_FILL_FILT_
# ----
# ----
#  FILL_FILL_FILL_FILL_RELE_
# ----
# ----
#  FILL_FILL_FILL_FILL_RELEE
# ----
# iter 12600, loss: 54.909615
# ----
#  !=
# ----
# ----
#  =
# ----
# ----
#  |
# ----
# ----
#  P
# ----
# ----
#  !
# ----
# iter 12700, loss: 55.488873
# ----
#  REL_ERETERERERERERERERERE
# ----
# ----
#  REL_ERETERERERERERERERETE
# ----
# ----
#  REL_ERETEREREREREREREREDE
# ----
# ----
#  REL_ERETEREREREREREREREEE
# ----
# ----
#  REL_ERETERERERERERERERE_E
# ----
# iter 12800, loss: 55.544268
# ----
#  seructifilterinterinterin
# ----
# ----
#  seructifilterinterinteren
# ----
# ----
#  seructifilterinterintered
# ----
# ----
#  seructifilterinterintere
# ----
# ----
#  seructifilterinterinterer
# ----
# iter 12900, loss: 56.270985
# ----
#  folter);
# }
#
# 	struct_filte
# ----
# ----
#  folter);
# }
#
# 	struct_fiste
# ----
# ----
#  folter);
# }
#
# 	struct_filt
# ----
# ----
#  folter);
# }
#
# 	struct_filta
# ----
# ----
#  folter);
# }
#
# 	struct_ficte
# ----
# iter 13000, loss: 57.138088
# ----
#  =
# ----
# ----
#  f
# ----
# ----
#  s
# ----
# ----
#  n
# ----
# ----
#  c
# ----
# iter 13100, loss: 57.623011
# ----
#  seruct_filter);
# }
#
# /*/
#
#
# ----
# ----
#  seruct_filter);
# }
#
# /*/
# 	s
# ----
# ----
#  seruct_filter);
# }
#
# /*/
# 	i
# ----
# ----
#  seruct_filter);
# }
#
# /*/
#
# ----
# ----
#  seruct_filter);
# }
#
# /*/
# 	r
# ----
# iter 13200, loss: 57.598892
# ----
#  inter_filter;
# }
#
# /*/
# 	int
# ----
# ----
#  inter_filter;
# }
#
# /*/
# 	ret
# ----
# ----
#  inter_filter;
# }
#
# /*/
# 	in
# ----
# ----
#  inter_filter;
# }
#
# /*/
# 	re
# ----
# ----
#  inter_filter;
# }
#
# /*/
#
# 	st
# ----
# iter 13300, loss: 57.736366
# ----
#  restruct_filter;
# }
#
# /*/
#
# ----
# ----
#  restruct_filter;
# }
#
# /*/
#
#
# ----
# ----
#  restruct_filter;
# }
#
# /*
#
#
# ----
# ----
#  restruct_filter;
# }
#
# /*/
#
# ----
# ----
#  restruct_filter;
# }
#
# /*/
# /
# ----
# iter 13400, loss: 57.519439
# ----
#  */
# 	returned);
# }
#
# /*/
# /*
#
# ----
# ----
#  */
# 	returned);
# }
#
# /*/
# /*
# ----
# ----
#  */
# 	returned);
# }
#
# /*/
# /*/
# ----
# ----
#  */
# 	returned);
# }
#
# /*/
# 	in
# ----
# ----
#  */
# 	returned);
# }
#
# /*/
# 	if
# ----
# iter 13500, loss: 57.694645
# ----
#  thactinterentinterentint
# ----
# ----
#  thactinterentinterenting
# ----
# ----
#  thactinterentinterensint
# ----
# ----
#  thactinterentinterensinte
# ----
# ----
#  thactinterentinterentinte
# ----
# iter 13600, loss: 57.986739
# ----
#  filter);
# }
#
# /*/
# /*/
#
# 	/*
#
# ----
# ----
#  filter);
# }
#
# /*/
# /*/
#
# 	/*
# ----
# ----
#  filter);
# }
#
# /*/
# /*
#
# 	/*
#
# ----
# ----
#  filter);
# }
#
# /*/
# /*
#
# 	/*
#
# ----
# ----
#  filter);
# }
#
# /*/
# /*
#
# 	/*
#
#
# ----
# iter 13700, loss: 58.028817
# ----
#  folter)
# {
# 	returned);
# }
#
#
# ----
# ----
#  folter)
# {
# 	returned)
# {
# 	s
# ----
# ----
#  folter)
# {
# 	returned)
# {
# 	i
# ----
# ----
#  folter)
# {
# 	returned)
# {
#
# ----
# ----
#  folter)
# {
# 	returned)
# {
# 	r
# ----
# iter 13800, loss: 57.815816
# ----
#  =
# ----
# ----
#  he
# ----
# ----
#  hes
# ----
# ----
#  *
# ----
# ----
#  her
# ----
# iter 13900, loss: 58.160653
# ----
#  {
# }
#
# struct);
# }
#
# struct
# ----
# ----
#  {
# }
#
# struct);
# }
#
# struct_s
# ----
# ----
#  {
# }
#
# struct);
# }
#
# struce
# ----
# ----
#  {
# }
#
# struct);
# }
#
# struct);
# ----
# ----
#  {
# }
#
# struct);
# }
#
# struct)
# ----
# iter 14000, loss: 57.947916
# ----
#  terentrent_filter);
# }
#
# /*
# ----
# ----
#  terentrent_filter);
# 	}
#
#
# ----
# ----
#  terentrent_filter);
# }
#
# 	*
# ----
# ----
#  terentrent_filter);
# }
#
# st
# ----
# ----
#  terentrent_filter);
# }
#
#
# ----
# iter 14100, loss: 58.303052
# ----
#  stack_filter);
# }
#
# struct
# ----
# ----
#  stack_filter);
# }
#
# struce
# ----
# ----
#  stack_filter);
# }
#
# struct_
# ----
# ----
#  stack_filter);
# }
#
# strucc
# ----
# ----
#  stack_filter);
# }
#
# struct)
# ----
# iter 14200, loss: 57.726705
# ----
#  s_stack_filter);
# 	struct
# ----
# ----
#  s_stack_filter);
# }
#
# struc
# ----
# ----
#  s_stack_filter);
# 	struct_
# ----
# ----
#  s_stack_filter);
# 	struce
# ----
# ----
#  s_stack_filter);
# 	struct)
# ----
# iter 14300, loss: 57.054131
# ----
#  int_syscall;
# }
#
# struct);
#
# ----
# ----
#  int_syscall;
# }
#
# struct
# ----
# ----
#  int_syscall;
# }
#
# struct_sy
# ----
# ----
#  int_syscall;
# }
#
# struct_re
# ----
# ----
#  int_syscall;
# }
#
# struct_fi
# ----
# iter 14400, loss: 56.733106
# ----
#  syscall);
# }
#
# struct_sysca
# ----
# ----
#  syscall);
# }
#
# struct_sysce
# ----
# ----
#  syscall);
# }
#
# struct_systa
# ----
# ----
#  syscall);
# }
#
# struct_sysco
# ----
# ----
#  syscall);
# }
#
# struct_syscu
# ----
# iter 14500, loss: 56.337652
# ----
#  syscall);
# }
#
# struct_sysca
# ----
# ----
#  syscall);
# }
#
# struct_systa
# ----
# ----
#  syscall);
# }
#
# struct_sysce
# ----
# ----
#  syscall);
# }
#
# struct_sysco
# ----
# ----
#  syscall);
# }
#
# struct_syscu
# ----
# iter 14600, loss: 56.117291
# ----
#  (syscall_syscall_syscall_
# ----
# ----
#  (syscall_syscall_syscall(
# ----
# ----
#  syscall_syscall_syscall_s
# ----
# ----
#  syscall_syscall_syscall(s
# ----
# ----
#  syscall_syscall_syscall);
# ----
# iter 14700, loss: 55.020753
# ----
#  syscall);
# cond_syscall(sy
# ----
# ----
#  syscall);
# cond_syscall);
#
# ----
# ----
#  syscall);
# cond_syscall_sy
# ----
# ----
#  syscall);
# cond_syscall(se
# ----
# ----
#  syscall);
# cond_syscall(si
# ----
# iter 14800, loss: 53.440377
# ----
#  syscall(syscall_syscall(s
# ----
# ----
#  syscall(syscall(syscall(s
# ----
# ----
#  syscall(syscall_syscall_s
# ----
# ----
#  syscall(syscall_syscall(c
# ----
# ----
#  syscall(syscall_syscall(f
# ----
# iter 14900, loss: 53.752263
# ----
#  all_syscall);
# cond_syscal
# ----
# ----
#  all_syscall);
# cond_syscar
# ----
# ----
#  all_syscall);
# cond_syscam
# ----
# ----
#  all_syscall);
# cond_syscas
# ----
# ----
#  all_syscall);
# cond_syscau
# ----
# iter 15000, loss: 55.380502
# ----
#  struct);
# }
#
# struct_struct
# ----
# ----
#  struct);
# }
#
# struct_stack_
# ----
# ----
#  struct);
# }
#
# struct_syscal
# ----
# ----
#  struct);
# }
#
# struct_systar
# ----
# ----
#  struct);
# }
#
# struct_struc_
# ----
# iter 15100, loss: 56.016360
# ----
#  stack_syscall);
# }
#
# struct
# ----
# ----
#  stack_syscall);
# }
#
# strucu
# ----
# ----
#  stack_syscall);
# }
#
# struce
# ----
# ----
#  stack_syscall);
# }
#
# struco
# ----
# ----
#  stack_syscall);
# }
#
# struca
# ----
# iter 15200, loss: 56.838213
# ----
#  reture_precure);
# }
#
# struc
# ----
# ----
#  reture_precure);
# }
#
# strur
# ----
# ----
#  reture_precure);
# }
#
# strut
# ----
# ----
#  reture_precure);
# }
#
# strum
# ----
# ----
#  reture_precure);
# }
#
# stru_
# ----
# iter 15300, loss: 57.209480
# ----
#  intired_syscallock_syscal
# ----
# ----
#  intired_syscallock_precur
# ----
# ----
#  intired_syscallock_systar
# ----
# ----
#  intired_syscallock_caller
# ----
# ----
#  intired_syscallock_syscar
# ----
# iter 15400, loss: 57.692780
# ----
#  torcust_rcu_torcu_torcure
# ----
# ----
#  torcust_rcu_torcu_torcust
# ----
# ----
#  torcust_rcu_torcu_torcu_t
# ----
# ----
#  torcust_rcu_torcu_torcu_s
# ----
# ----
#  torcust_rcu_torcu_torcu_p
# ----
# iter 15500, loss: 57.870568
# ----
#  */
# 	returcunt_rcu_torture
# ----
# ----
#  */
# 	returcunt_rcu_torcure
# ----
# ----
#  */
# 	returcunt_rcu_tercure
# ----
# ----
#  */
# 	returcunt_rcu_terture
# ----
# ----
#  */
# 	returcunt_rcu_torturc
# ----
# iter 15600, loss: 57.713247
# ----
#  toret_reture_stack);
# 		/*
# ----
# ----
#  toret_reture_stack);
#
# ----
# ----
#  toret_reture_stack);
# 	}
#
# ----
# ----
#  toret_reture_stack);
# {
#
# ----
# ----
#  toret_reture_stack);
# 	}
#
#
# ----
# iter 15700, loss: 58.084614
# ----
#  uctireu_torcu_torcu_torcu
# ----
# ----
#  uctireu_torcu_torcu_tortu
# ----
# ----
#  uctireu_torcu_torcu_toret
# ----
# ----
#  uctireu_torcu_torture_sta
# ----
# ----
#  uctireu_torcu_torcu_torto
# ----
# iter 15800, loss: 58.453125
# ----
#  =)
# 			reture_strcu_tortur
# ----
# ----
#  =)
# 			reture_strcu_torcur
# ----
# ----
#  =)
# 			reture_strcu_torcu_
# ----
# ----
#  =)
# 			reture_strcu_torcun
# ----
# ----
#  =)
# 			reture_strcu_torcul
# ----
# iter 15900, loss: 59.043219
# ----
#  stru_torture);
# 				reture
# ----
# ----
#  stru_torture);
# 			reture
# ----
# ----
#  stru_torture);
# 			reture_
# ----
# ----
#  stru_torture);
# 			reture)
# ----
# ----
#  stru_torture);
# 			returet
# ----
# iter 16000, loss: 58.714073
# ----
#  */
# 	intire_torture);
# }
#
#
# ----
# ----
#  */
# 	intire_torture);
# 	int
# ----
# ----
#  */
# 	intire_torture);
# 		re
# ----
# ----
#  */
# 	intire_torture);
# 		in
# ----
# ----
#  */
# 	intire_torture);
# 			r
# ----
# iter 16100, loss: 58.478628
# ----
#  cu_torture);
# 	}
# 		reture
# ----
# ----
#  cu_torture);
# 	}
# 		reture_
# ----
# ----
#  cu_torture);
# 	}
# 		returcu
# ----
# ----
#  cu_torture);
# 	}
# 		reture)
# ----
# ----
#  cu_torture);
# 	}
# 		returee
# ----
# iter 16200, loss: 58.018849
# ----
#  torture);
# 		stru_torture_
# ----
# ----
#  torture);
# 		stru_torcure_
# ----
# ----
#  torture);
# 		stru_torture
# ----
# ----
#  torture);
# 		stru_torcu_to
# ----
# ----
#  torture);
# 		stru_torture)
# ----
# iter 16300, loss: 58.214935
# ----
#  0;
# }
#
# struct_rcu_torture_
# ----
# ----
#  0;
# }
#
# struct_rcu_torture
# ----
# ----
#  0;
# }
#
# struct_rcu_torturt_
# ----
# ----
#  0;
# }
#
# struct_rcu_torture(
# ----
# ----
#  0;
# }
#
# struct_rcu_torture)
# ----
# iter 16400, loss: 58.697740
# ----
#  */
# 	int(rcu_torture_stall
# ----
# ----
#  */
# 	int(rcu_torture_sture
# ----
# ----
#  */
# 	int(rcu_torture_stare
# ----
# ----
#  */
# 	int(rcu_torture_state
# ----
# ----
#  */
# 	int(rcu_torture_stati
# ----
# iter 16500, loss: 58.508154
# ----
#  torture);
# {
# 	struct_rcu_t
# ----
# ----
#  torture);
# {
# 	struct_rcure
# ----
# ----
#  torture);
# {
# 	struct_rcu_s
# ----
# ----
#  torture);
# {
# 	struct_rcu_r
# ----
# ----
#  torture);
# {
# 	struct_rcu_b
# ----
# iter 16600, loss: 58.595364
# ----
#  torture_stare_stack);
# 	}
#
# ----
# ----
#  torture_stare_stack);
#
# ----
# ----
#  torture_stare_stack);
# 		r
# ----
# ----
#  torture_stare_stack);
# 		i
# ----
# ----
#  torture_stare_stack);
# }
#
#
# ----
# iter 16700, loss: 58.085468
# ----
#  RONU_stare_stack);
# 	}
#
#
# ----
# ----
#  RONU_stare_stack);
# 	}
#
# 	c
# ----
# ----
#  RONU_stare_stack);
# 	}
#
# 	r
# ----
# ----
#  RONU_stare_stack);
# 	}
#
# 	i
# ----
# ----
#  RONU_stare_stack);
# 	}
# 	st
# ----
# iter 16800, loss: 58.360042
# ----
#  *
# ----
# ----
#  =
# ----
# ----
#  f
# ----
# ----
#  t
# ----
# ----
#  r
# ----
# iter 16900, loss: 58.046268
# ----
#  torture);
# 		/*
#
# ----
# ----
#  torture);
# 		/*
#
# ----
# ----
#  torture);
# 		/*
# 							sta
# ----
# ----
#  torture);
# 		/*
# 							str
# ----
# ----
#  torture);
# 		/*
# 							st
# ----
# iter 17000, loss: 57.809810
# ----
#  */
# /*
# #indided.
# {
# 	inture
# ----
# ----
#  */
# /*
# #indided.
# 		/*
# 	int
# ----
# ----
#  */
# /*
# #indided.
# 		/*
# 	if
# ----
# ----
#  */
# /*
# #indided.
# 		/*
#
# 	in
# ----
# ----
#  */
# /*
# #indided.
# 		/*
# 	in
# ----
# iter 17100, loss: 59.173693
# ----
#  torture_torcu_torture);
#
# ----
# ----
#  torture_torcu_torcu_torcu
# ----
# ----
#  torture_torcu_torcu_tortu
# ----
# ----
#  torture_torcu_torture);
#
#
# ----
# ----
#  torture_torcu_torture);
# }
# ----
# iter 17200, loss: 60.194859
# ----
#  prrater);
# 	}
# }
#
# /*/
#
# 	int
# ----
# ----
#  prrater);
# 	}
# }
#
# /*/
#
# 	ret
# ----
# ----
#  prrater);
# 	}
# }
#
# /*/
#
# 	in
# ----
# ----
#  prrater);
# 	}
# }
#
# /*/
#
#
# ----
# ----
#  prrater);
# 	}
# }
#
# /*/
#
#
# ----
# iter 17300, loss: 60.633001
# ----
#  inter_torcu_torture);
# 	}
#
# ----
# ----
#  inter_torcu_torture);
# }
#
#
# ----
# ----
#  inter_torcu_torture);
# 	in
# ----
# ----
#  inter_torcu_torture);
# 	if
# ----
# ----
#  inter_torcu_torture);
# 	re
# ----
# iter 17400, loss: 60.721932
# ----
#  the
# 		reture
# 			reture
#
# ----
# ----
#  the
# 		reture
# 				reture
# ----
# ----
#  the
# 		reture
# 			reture
# ----
# ----
#  the
# 		reture
# 			reture
# 	i
# ----
# ----
#  the
# 		reture
# 			reture
#
# ----
# iter 17500, loss: 61.011658
# ----
#  */
# }
#
# /*
#
# 	int_inger_tore
# ----
# ----
#  */
# }
#
# /*
#
# 	int_inger_cond
# ----
# ----
#  */
# }
#
# /*
#
# 	int_inger_stat
# ----
# ----
#  */
# }
#
# /*
#
# 	int_inger_torc
# ----
# ----
#  */
# }
#
# /*
#
# 	int_inger_torn
# ----
# iter 17600, loss: 61.292312
# ----
#  the
# ----
# ----
#  *
# ----
# ----
#  f
# ----
# ----
#  t
# ----
# ----
#  g
# ----
# iter 17700, loss: 61.384907
# ----
#  ing_block);
# }
#
# /*/
#
# 	retu
# ----
# ----
#  ing_block);
# }
#
# /*/
#
# 	int
# ----
# ----
#  ing_block);
# }
#
# /*/
#
# 	int_
# ----
# ----
#  ing_block);
# }
#
# /*/
#
# 	inti
# ----
# ----
#  ing_block);
# }
#
# /*/
#
# 	if
# ----
# iter 17800, loss: 61.409315
# ----
#  0;
# }
#
# /*/
#
# 	interinter_co
# ----
# ----
#  0;
# }
#
# /*/
#
# 	interintered
# ----
# ----
#  0;
# }
#
# /*/
#
# 	interinterign
# ----
# ----
#  0;
# }
#
# /*/
#
# 	interinter_bo
# ----
# ----
#  0;
# }
#
# /*/
#
# 	interinterint
# ----
# iter 17900, loss: 61.523341
# ----
#  */
# }
#
# }
#
# /*/
#
# 	int_reture
# ----
# ----
#  */
# }
#
# }
#
# /*/
#
# 	int_return
# ----
# ----
#  */
# }
#
# }
#
# /*/
#
# 	int_returt
# ----
# ----
#  */
# }
#
# }
#
# /*/
#
# 	int_returc
# ----
# ----
#  */
# }
#
# }
#
# /*/
#
# 	int_retur
# ----
# iter 18000, loss: 61.536178
# ----
#  */
# /*
# #intire_inter_torcu
# ----
# ----
#  */
# /*
# #intire_inter_stare
# ----
# ----
#  */
# /*
# #intire_inter_tore_
# ----
# ----
#  */
# /*
# #intire_inter_stati
# ----
# ----
#  */
# /*
# #intire_inter_toret
# ----
# iter 18100, loss: 61.669586
# ----
#  0;
# }
#
# /*/
#
# 	reture_stare
# ----
# ----
#  0;
# }
#
# /*/
#
# 	reture_state
# ----
# ----
#  0;
# }
#
# /*/
#
# 	reture_stack_
# ----
# ----
#  0;
# }
#
# /*/
#
# 	reture_stack
# ----
# ----
#  0;
# }
#
# /*/
#
# 	reture_stade
# ----
# iter 18200, loss: 61.692465
# ----
#  {
# 			reture_stareater_sta
# ----
# ----
#  {
# 			reture_stareater_pre
# ----
# ----
#  {
# 			reture_stareater_tor
# ----
# ----
#  {
# 			reture_stareater_tar
# ----
# ----
#  {
# 			reture_stareater_tas
# ----
# iter 18300, loss: 61.563753
# ----
#  inter_stater_staret_stare
# ----
# ----
#  inter_stater_stare_staret
# ----
# ----
#  inter_stater_stare_stare
# ----
# ----
#  inter_stater_stare_stare_
# ----
# ----
#  inter_stater_stare_stater
# ----
# iter 18400, loss: 61.387729
# ----
#  0;
# 	}
#
# /*/
#
# 		reture
# 		re
# ----
# ----
#  0;
# 	}
#
# /*/
#
# 		reture
#
# ----
# ----
#  0;
# 	}
#
# /*/
#
# 		reture
# 		if
# ----
# ----
#  0;
# 	}
#
# /*/
#
# 		reture
# 		st
# ----
# ----
#  0;
# 	}
#
# /*/
#
# 		reture
# 			r
# ----
# iter 18500, loss: 61.549686
# ----
#  ter_preat_returned_state
# ----
# ----
#  ter_preat_returned_stare
# ----
# ----
#  ter_preat_returned_staret
# ----
# ----
#  ter_preat_returned_stap_s
# ----
# ----
#  ter_preat_returned_stater
# ----
# iter 18600, loss: 61.745751
# ----
#  REL_SERE_SERE_SERE_SERE_S
# ----
# ----
#  REL_SERE_SERE_SERE_SER_SE
# ----
# ----
#  REL_SERE_TERE_SERE_SERE_S
# ----
# ----
#  REL_SERE_SERE_TERE_SERE_S
# ----
# ----
#  REL_SERE_SERE_SERE_TERE_S
# ----
# iter 18700, loss: 61.662499
# ----
#  */
#
# 		reture
# ----
# ----
#  */
#
# 	reture
# ----
# ----
#  */
#
# 		return
# ----
# ----
#  */
#
# 	return
# ----
# ----
#  */
#
# 	returt
# ----
# iter 18800, loss: 61.611867
# ----
#  fore_preatere_preture
#
# ----
# ----
#  fore_preatere_preture
# 		r
# ----
# ----
#  fore_preatere_preture
# 	re
# ----
# ----
#  fore_preatere_preture
#
# ----
# ----
#  fore_preatere_preture
# 		i
# ----
# iter 18900, loss: 61.651620
# ----
#  TERE_SERE_TERE_SERE_SERE_
# ----
# ----
#  TERE_SERE_SERE_SERE_SERE_
# ----
# ----
#  TERE_SERE_SERE_TERE_SERE_
# ----
# ----
#  TERE_SERE_TERE_SERE_TERE_
# ----
# ----
#  TERE_SERE_SERE_TERE_SEAT_
# ----
# iter 19000, loss: 61.490244
# ----
#  interintereatereture
# 	in
# ----
# ----
#  interintereatereture
# 	if
# ----
# ----
#  interintereatereture
# 	int
# ----
# ----
#  interintereatereture
# 	ine
# ----
# ----
#  interintereatereture
# 	ing
# ----
# iter 19100, loss: 61.957136
# ----
#  he
# 	in
# ----
# ----
#  he
# 	int
# ----
# ----
#  he
# 	ing
# ----
# ----
#  he
# 	ine
# ----
# ----
#  he
# 	if
# ----
# iter 19200, loss: 61.975199
# ----
#  */
# /*/
#
# 	returned_stater
# ----
# ----
#  */
# /*/
#
# 	returned_stalle
# ----
# ----
#  */
# /*/
#
# 	returned_statere
# ----
# ----
#  */
# /*/
#
# 	returned_state
# ----
# ----
#  */
# /*/
#
# 	returned_stater_
# ----
# iter 19300, loss: 62.014370
# ----
#  SALT_SERE_SERE_SERE_SERE_
# ----
# ----
#  SALE_SERE_SERE_SERE_SERE_
# ----
# ----
#  SALT_SERE_SERE_SERE_SEL__
# ----
# ----
#  SALT_SERE_SERE_SERE_SER_S
# ----
# ----
#  SALT_SERE_SERE_SERE_SERE(
# ----
# iter 19400, loss: 62.106717
# ----
#  thatalindindindindedind
# ----
# ----
#  thatalindindindindeding
# ----
# ----
#  thatalindindindindedinded
# ----
# ----
#  thatalindindindindedinde
# ----
# ----
#  thatalindindindindedinn
# ----
# iter 19500, loss: 62.223566
# ----
#  thendindindedindedind
# ----
# ----
#  thendindindedindeding
# ----
# ----
#  thendindindedindedint
# ----
# ----
#  thendindindedindedinn
# ----
# ----
#  thendindindedindedinde
# ----
# iter 19600, loss: 62.264383
# ----
#  chindindereatinederentit
# ----
# ----
#  chindindereatinederentin
# ----
# ----
#  chindindereatinederendin
# ----
# ----
#  chindindereatinederendind
# ----
# ----
#  chindindereatinederentind
# ----
# iter 19700, loss: 62.030454
# ----
#  FINT_REATE_SERE_TARE_SERE
# ----
# ----
#  FINT_REATE_SERE_TARE_TERE
# ----
# ----
#  FINT_REATE_SERE_TARE_SEAT
# ----
# ----
#  FINT_REATE_SERE_TARE_SERT
# ----
# ----
#  FINT_REATE_SERE_TART_REAT
# ----
# iter 19800, loss: 62.056016
# ----
#  stack);
# }
#
# /*/
# 	int_retur
# ----
# ----
#  stack);
# }
#
# /*/
# 	int_ret_r
# ----
# ----
#  stack);
# }
#
# /*/
# 	int_resta
# ----
# ----
#  stack);
# }
#
# /*/
# 	int_restr
# ----
# ----
#  stack);
# }
#
# /*/
# 	int_ret_p
# ----
# iter 19900, loss: 62.853302
# ----
#  fore_stack)
# {
# 	returned,
# ----
# ----
#  fore_stack)
# {
# 	return_lon
# ----
# ----
#  fore_stack)
# {
# 	return
# ----
# ----
#  fore_stack)
# {
# 	return_lop
# ----
# ----
#  fore_stack)
# {
# 	returned_n
# ----
# iter 20000, loss: 62.829405
# ----
#  =)
# {
# 	return_struct,
#
# ----
# ----
#  =)
# {
# 	return_struct,
# 		s
# ----
# ----
#  =)
# {
# 	return_struct,
#
# ----
# ----
#  =)
# {
# 	return_struct,
# 		r
# ----
# ----
#  =)
# {
# 	return_struct,
#
# ----
# iter 20100, loss: 62.673861
# ----
#  *=
# 			return_struct,
#
# ----
# ----
#  *=
# 			return_struct,
#
# ----
# ----
#  *=
# 			return_struct,
# 			r
# ----
# ----
#  *=
# 			return_struct,
# 			s
# ----
# ----
#  *=
# 			return_struct,
# 			i
# ----
# iter 20200, loss: 62.174084
# ----
#  structure_structurestruct
# ----
# ----
#  structure_structure_struc
# ----
# ----
#  structure_structurestrunt
# ----
# ----
#  structure_structurestrucu
# ----
# ----
#  structure_structure_state
# ----
# iter 20300, loss: 62.014380
# ----
#  threcustereture_structure
# ----
# ----
#  threcustereture_structurn
# ----
# ----
#  threcustereture_structore
# ----
# ----
#  threcustereture_struct_re
# ----
# ----
#  threcustereture_structurt
# ----
# iter 20400, loss: 61.627839
# ----
#  =);
# 	}
#
# /*
#
# 	struct_struc
# ----
# ----
#  =);
# 	}
#
# /*
#
# 	struct_stade
# ----
# ----
#  =);
# 	}
#
# /*
#
# 	struct_state
# ----
# ----
#  =);
# 	}
#
# /*
#
# 	struct_stape
# ----
# ----
#  =);
# 	}
#
# /*
#
# 	struct_stati
# ----
# iter 20500, loss: 60.847380
# ----
#  */
# #intireed_ppreat_retur
# ----
# ----
#  */
# #intireed_ppreat_state
# ----
# ----
#  */
# #intireed_ppreat_resta
# ----
# ----
#  */
# #intireed_ppreat_reati
# ----
# ----
#  */
# #intireed_ppreat_reade
# ----
# iter 20600, loss: 60.835315
# ----
#  /
#
# 	reture_structure_that
# ----
# ----
#  /
#
# 	reture_structure_the
# ----
# ----
#  /
#
# 	reture_structureater
# ----
# ----
#  /
#
# 	reture_structureatere
# ----
# ----
#  /
#
# 	reture_structure_thee
# ----
# iter 20700, loss: 60.836160
# ----
#  thread_structurned_state
# ----
# ----
#  thread_structurestruct_re
# ----
# ----
#  thread_structurestruct
# ----
# ----
#  thread_structurned_stater
# ----
# ----
#  thread_structurned_lock_s
# ----
# iter 20800, loss: 60.954088
# ----
#  (stack);
# }
# }
#
# /*
#
# ----
# ----
#  (stack);
# }
# }
#
# /*
#
#
# ----
# ----
#  (stack);
# }
# }
#
# /*
#
# ----
# ----
#  (stack);
# }
# }
#
# /*
#
#
# ----
# ----
#  (stack);
# }
# }
#
# /*
# 							s
# ----
# iter 20900, loss: 61.213754
# ----
#  *
#
# ----
# ----
#  *
#
# ----
# ----
#  *
# 																						r
# ----
# ----
#  *
# 																						s
# ----
# ----
#  *
# 																						i
# ----
# iter 21000, loss: 61.423037
# ----
#  =)
#
# ----
# ----
#  =)
#
# ----
# ----
#  =)
# 																					r
# ----
# ----
#  =)
# 																					s
# ----
# ----
#  =)
# 																					i
# ----
# iter 21100, loss: 61.053308
# ----
#  *
#
# ----
# ----
#  */
#
# ----
# ----
#  *
#
# ----
# ----
#  */
#
# ----
# ----
#  *
# 																						r
# ----
# iter 21200, loss: 61.081883
# ----
#  fore_structurestruct_rest
# ----
# ----
#  fore_structurestruct_reat
# ----
# ----
#  fore_structurestruct_read
# ----
# ----
#  fore_structurestruct_rere
# ----
# ----
#  fore_structurestruct_retu
# ----
# iter 21300, loss: 60.735772
# ----
#  *preat_uproct_uproct_upro
# ----
# ----
#  *preat_uproct_uprock_cpu_
# ----
# ----
#  *preat_uproct_uproct_upre
# ----
# ----
#  *preat_uprock_cpureture
# ----
# ----
#  *preat_uproct_uprock_cpuc
# ----
# iter 21400, loss: 59.960840
# ----
#  custare);
# }
#
# }
#
# struct
# ----
# ----
#  custare);
# }
#
# }
#
# struct_re
# ----
# ----
#  custare);
# }
#
# }
#
# struct_up
# ----
# ----
#  custare);
# }
#
# }
#
# struct_un
# ----
# ----
#  custare);
# }
#
# }
#
# struct_bp
# ----
# iter 21500, loss: 59.352785
# ----
#  */
# 	returned_struct,
#
# ----
# ----
#  */
# 	returned_struct,
#
# ----
# ----
#  */
# 	returned_struct,
# 			r
# ----
# ----
#  */
# 	returned_struct,
# 			i
# ----
# ----
#  */
# 	returned_struct,
# 	}
#
#
# ----
# iter 21600, loss: 58.948148
# ----
#  proct_uprobe_structuretur
# ----
# ----
#  proct_uprobe_structure_tr
# ----
# ----
#  proct_uprobe_structure_to
# ----
# ----
#  proct_uprobe_structure_pr
# ----
# ----
#  proct_uprobe_structure_fi
# ----
# iter 21700, loss: 58.458872
# ----
#  TERE_TERE_TERE_TERE_TERE_
# ----
# ----
#  TERE_TERE_TERE_TERE_RERE_
# ----
# ----
#  TERE_TERE_TERE_TERE_TEREE
# ----
# ----
#  TERE_TERE_TERE_TERE_TERE(
# ----
# ----
#  TERE_TERE_TERE_TERE_TERT_
# ----
# iter 21800, loss: 57.965892
# ----
#  0;
# }
#
# struct_uprobe_struc
# ----
# ----
#  0;
# }
#
# struct_uprobe_state
# ----
# ----
#  0;
# }
#
# struct_uprobe_turne
# ----
# ----
#  0;
# }
#
# struct_uprobe_file_
# ----
# ----
#  0;
# }
#
# struct_uprobe_stru_
# ----
# iter 21900, loss: 57.361114
# ----
#  s
# ----
# ----
#  d
# ----
# ----
#  e
# ----
# ----
#  g
# ----
# ----
#  t
# ----
# iter 22000, loss: 57.774843
# ----
#  interint
# ----
# ----
#  interine
# ----
# ----
#  interin
# ----
# ----
#  interer
# ----
# ----
#  interen
# ----
# iter 22100, loss: 58.805063
# ----
#  FINT_RERE_TARE_TERE_TARE_
# ----
# ----
#  FINT_RERE_TARE_TERER_RERE
# ----
# ----
#  FINT_RERE_TARE_TERE_TERE_
# ----
# ----
#  FINT_RERE_TARE_TERER_RER_
# ----
# ----
#  FINT_RERE_TARE_TERER_RERT
# ----
# iter 22200, loss: 59.167870
# ----
#  structurestruct_uprobe_st
# ----
# ----
#  structurestruct_uprobe_tr
# ----
# ----
#  structurestruct_uprobe_pr
# ----
# ----
#  structurestruct_uprobe_fo
# ----
# ----
#  structurestruct_uproct_up
# ----
# iter 22300, loss: 59.651955
# ----
#  intistate_structure);
# }
#
#
# ----
# ----
#  intistate_structure);
# }
#
# ----
# ----
#  intistate_structure);
# }
# #
# ----
# ----
#  intistate_structure);
# }
# }
# ----
# ----
#  intistate_structure);
# }
# s
# ----
# iter 22400, loss: 59.641752
# ----
#  lock);
# }
#
# structurestruct
# ----
# ----
#  lock);
# }
#
# structurestruce
# ----
# ----
#  lock);
# }
#
# structurestrucu
# ----
# ----
#  lock);
# }
#
# structurestruc_
# ----
# ----
#  lock);
# }
#
# structurestrucs
# ----
# iter 22500, loss: 59.834684
# ----
#  struct_rcu_struct_rcu_str
# ----
# ----
#  struct_rcu_struct_rcu_sta
# ----
# ----
#  struct_rcu_struct_rcu_tor
# ----
# ----
#  struct_rcu_struct_rcu_for
# ----
# ----
#  struct_rcu_struct_rcu_sto
# ----
# iter 22600, loss: 59.840664
# ----
#  CUL_stack_stack);
# }
#
# /*/
#
# ----
# ----
#  CUL_stack_stack);
# }
#
# /*
#
# ----
# ----
#  CUL_stack_stack);
# }
#
# stat
# ----
# ----
#  CUL_stack_stack);
# 	}
#
# /*
#
# ----
# ----
#  CUL_stack_stack);
# 	}
#
# /*
# ----
# iter 22700, loss: 59.534370
# ----
#  */
# /*/
# struct_rcu_struct
# ----
# ----
#  */
# /*/
# struct_rcu_struct_
# ----
# ----
#  */
# /*/
# struct_rcu_state)
# ----
# ----
#  */
# /*/
# struct_rcu_stater
# ----
# ----
#  */
# /*/
# struct_rcu_structu
# ----
# iter 22800, loss: 59.371002
# ----
#  */
# /*/
# statice_struct_rcu
# ----
# ----
#  */
# /*/
# statice_struct_ret
# ----
# ----
#  */
# /*/
# statice_struct_res
# ----
# ----
#  */
# /*/
# statice_struct_rea
# ----
# ----
#  */
# /*/
# statice_struct_rec
# ----
# iter 22900, loss: 59.615710
# ----
#  (custack);
# }
#
# static_stat
# ----
# ----
#  (custack);
# }
#
# statice_sta
# ----
# ----
#  (custack);
# }
#
# static_stru
# ----
# ----
#  (custack);
# }
#
# static_stad
# ----
# ----
#  (custack);
# }
#
# static_stac
# ----
# iter 23000, loss: 59.611189
# ----
#  interind
# ----
# ----
#  interint
# ----
# ----
#  interine
# ----
# ----
#  interinde
# ----
# ----
#  intered
# ----
# iter 23100, loss: 59.567926
# ----
#  lontirned
# ----
# ----
#  lontirne
# ----
# ----
#  lontirnt
# ----
# ----
#  lonting
# ----
# ----
#  longing
# ----
# iter 23200, loss: 59.556134
# ----
#  thinederentingintingered
# ----
# ----
#  thinederentingintingerent
# ----
# ----
#  thinederentingintingeren
# ----
# ----
#  thinederentingintingerer
# ----
# ----
#  thinederentingintingerend
# ----
# iter 23300, loss: 59.495188
# ----
#  {
# }
#
# /*/
#
# 	returned);
# }
#
#
# ----
# ----
#  {
# }
#
# /*/
#
# ...
# 																	r
# ----
# ----
#  struct
# 																	d
# ----
# ----
#  struct
# 																	c
# ----
# iter 225400, loss: 52.143166
# ----
#  */
# 	return;
# }
#
# static
# ----
# ----
#  */
# 	return;
# }
#
# statif
# ----
# ----
#  */
# 	return;
# }
#
# statis
# ----
# ----
#  */
# 	return;
# }
#
# statit
# ----
# ----
#  */
# 	return;
# }
#
# statin
# ----
# iter 225500, loss: 52.706242
# ----
#  id
# ----
# ----
#  if
# ----
# ----
#  ide
# ----
# ----
#  is
# ----
# ----
#  it
# ----
# iter 225600, loss: 52.366444
# ----
#  lock)
# 		return;
#
# 	return
# ----
# ----
#  lock)
# 		return;
#
# 	return;
# ----
# ----
#  lock)
# 		return;
#
# 	return_
# ----
# ----
#  lock)
# 		return;
#
# 	returne
# ----
# ----
#  lock)
# 		return;
#
# 	returns
# ----
# iter 225700, loss: 52.389756
# ----
#  */
# 	return;
# }
#
# static
# ----
# ----
#  */
# 	return;
# }
#
# statif
# ----
# ----
#  */
# 	return;
# }
#
# statis
# ----
# ----
#  */
# 	return;
# }
#
# statit
# ----
# ----
#  */
# 	return;
# }
#
# statin
# ----
# iter 225800, loss: 52.471427
# ----
#  the
# ----
# ----
#  thes
# ----
# ----
#  thet
# ----
# ----
#  ther
# ----
# ----
#  thee
# ----
# iter 225900, loss: 52.495520
# ----
#  =;
# }
#
# static
# 		}
# 	}
#
# 	if
# ----
# ----
#  =;
# }
#
# static
# 		}
# 	}
# 	retu
# ----
# ----
#  =;
# }
#
# static
# 		}
# 	}
#
# /*
#
# ----
# ----
#  =;
# }
#
# static
# 		}
# 	}
#
# /*
#
# ----
# ----
#  =;
# }
#
# static
# 		}
# 	}
# 	ret
# ----
# iter 226000, loss: 52.380758
# ----
#  */
# 	struct
# ----
# ----
#  */
# 	return
# ----
# ----
#  */
# 	strunt
# ----
# ----
#  */
# 	struce
# ----
# ----
#  */
# 	strucp
# ----
# iter 226100, loss: 52.411220
# ----
#  */
# 	struct(statch_reader_
# ----
# ----
#  */
# 	struct(statch_reader(
# ----
# ----
#  */
# 	struct(statch_readed(
# ----
# ----
#  */
# 	struct(statch_readed_
# ----
# ----
#  */
# 	struct(statch_readere
# ----
# iter 226200, loss: 51.876593
# ----
#  */
# static
# ----
# ----
#  */
# struct
# ----
# ----
#  */
# statif
# ----
# ----
#  */
# statit
# ----
# ----
#  */
# statim
# ----
# iter 226300, loss: 51.075471
# ----
#  the
# ----
# ----
#  thes
# ----
# ----
#  thet
# ----
# ----
#  ther
# ----
# ----
#  thee
# ----
# iter 226400, loss: 51.285289
# ----
#  ext;
# }
#
# static
# ----
# ----
#  ext;
# }
#
# statif
# ----
# ----
#  ext;
# }
#
# statit
# ----
# ----
#  ext;
# }
#
# statis
# ----
# ----
#  ext;
# }
#
# statin
# ----
# iter 226500, loss: 51.742974
# ----
#  that
# ----
# ----
#  thet
# ----
# ----
#  the
# ----
# ----
#  ther
# ----
# ----
#  cher
# ----
# iter 226600, loss: 52.449144
# ----
#  */
# 	return;
# }
#
# static
# ----
# ----
#  */
# 	return;
# }
#
# statif
# ----
# ----
#  */
# 	return;
# }
#
# statis
# ----
# ----
#  */
# 	return;
# }
#
# statit
# ----
# ----
#  */
# 	return;
# }
#
# statin
# ----
# iter 226700, loss: 52.724647
# ----
#  the
#
# ----
# ----
#  the
# ----
# ----
#  the
#
# ----
# ----
#  thes
# ----
# ----
#  thet
# ----
# iter 226800, loss: 52.438408
# ----
#  */
# 	return;
# }
#
# static
# ----
# ----
#  */
# 	return;
# }
#
# statif
# ----
# ----
#  */
# 	return;
# }
#
# statit
# ----
# ----
#  */
# 	return;
# }
#
# statis
# ----
# ----
#  */
# 	return;
# }
#
# statin
# ----
# iter 226900, loss: 51.877879
# ----
#  */
# static
# ----
# ----
#  */
# struct
# ----
# ----
#  */
# statis
# ----
# ----
#  */
# statit
# ----
# ----
#  */
# statim
# ----
# iter 227000, loss: 51.127505
# ----
#  struct(struct_requele();
#
# ----
# ----
#  struct(struct_requele(str
# ----
# ----
#  struct(struct_requere(str
# ----
# ----
#  struct(struct_requele(sta
# ----
# ----
#  struct(struct_requele(siz
# ----
# iter 227100, loss: 50.849573
# ----
#  prined_lock_return;
# }
#
# /*
# ----
# ----
#  prined_lock_return;
# }
#
# st
# ----
# ----
#  prined_lock_return;
# 	retu
# ----
# ----
#  prined_lock_return;
#
# 	if
# ----
# ----
#  prined_lock_return;
#
# 	ret
# ----
# iter 227200, loss: 50.847806
# ----
#  0;
# }
#
# static
# ----
# ----
#  0;
# }
#
# struct
# ----
# ----
#  0;
# }
#
# statit
# ----
# ----
#  0;
# }
#
# statim
# ----
# ----
#  0;
# }
#
# statin
# ----
# iter 227300, loss: 50.542557
# ----
#  foresing
# 			return;
# }
#
# /*
# ----
# ----
#  foresing
# 			return;
# }
#
# st
# ----
# ----
#  foresing
# 			return;
#
# 	if
# ----
# ----
#  foresing
# 			return;
#
# 	/*
# ----
# ----
#  foresing
# 			return;
#
# 	/*
#
# ----
# iter 227400, loss: 49.758418
# ----
#  return;
# 	return
# 			return
# ----
# ----
#  return;
#
# 	return;
# }
#
# stat
# ----
# ----
#  return;
#
# 	return;
#
# 	retur
# ----
# ----
#  return;
#
# 	return;
# }
#
# /*
#
# ----
# ----
#  return;
# 	return
# 			returc
# ----
# iter 227500, loss: 49.953267
# ----
#  ->size);
# 	return
# ----
# ----
#  ->size);
# 	return						}
#
# ----
# ----
#  ->size);
# 	return							re
# ----
# ----
#  ->size);
# 	return
# ----
# ----
#  ->size);
# 	return								r
# ----
# iter 227600, loss: 49.447176
# ----
#  struct_return;
# }
#
# static
# ----
# ----
#  struct_return;
# }
#
# statit
# ----
# ----
#  struct_return;
# }
#
# statin
# ----
# ----
#  struct_return;
# }
#
# statim
# ----
# ----
#  struct_return;
# }
#
# static
#
# ----
# iter 227700, loss: 49.268052
# ----
#  CONFIG_NULL);
# 	return;
# }
#
# ----
# ----
#  CONFIG_NULL);
# 	return;
#
#
# ----
# ----
#  CONFIG_NULL);
# 	return"0;
#
# ----
# ----
#  CONFIG_NULL);
# 	return;
#
# ----
# ----
#  CONFIG_NULL);
# 	return;
# 	i
# ----
# iter 227800, loss: 51.819909
# ----
#  CONFIG_NULL);
# 	return;
#
# ----
# ----
#  CONFIG_NULL);
# 	return;
#
#
# ----
# ----
#  CONFIG_NULL);
# 	return;
# 	i
# ----
# ----
#  CONFIG_NULL);
# 	return;
# 	}
# ----
# ----
#  CONFIG_NULL);
# 	return;
# }
#
# ----
# iter 227900, loss: 53.564636
# ----
#  struct_read_lock_read_lon
# ----
# ----
#  struct_read_lock_read_loc
# ----
# ----
#  struct_read_lock_read_rea
# ----
# ----
#  struct_read_lock_read_ren
# ----
# ----
#  struct_read_lock_read_ret
# ----
# iter 228000, loss: 54.565301
# ----
#  long
# ----
# ----
#  lont
# ----
# ----
#  lond
# ----
# ----
#  lock
# ----
# ----
#  the
# ----
# iter 228100, loss: 55.269741
# ----
#  struct_renting
# ----
# ----
#  struct_conting
# ----
# ----
#  struct_contint
# ----
# ----
#  struct_rentint
# ----
# ----
#  struct_requere
# ----
# iter 228200, loss: 55.461354
# ----
#  */
# 	struct_rend_long_time
# ----
# ----
#  */
# 	struct_rend_long_fine
# ----
# ----
#  */
# 	struct_rend_long_fint
# ----
# ----
#  */
# 	struct_rend_long_fing
# ----
# ----
#  */
# 	struct_rend_long_rent
# ----
# iter 228300, loss: 55.770014
# ----
#  TINTINT_INT,	},
#
# ----
# ----
#  TINTINT_INT,	},
# 						cpu
# ----
# ----
#  ITTINT_INT,	},
#
# ----
# ----
#  TINTINT_INT,	},
#
# ----
# ----
#  TINTINT_INT,	},
# 								_
# ----
# iter 228400, loss: 55.842154
# ----
#  structide_structide_struc
# ----
# ----
#  structide_struct_renting
# ----
# ----
#  structide_struct_rentint
# ----
# ----
#  structide_struct_rending
# ----
# ----
#  structide_struct_rendint
# ----
# iter 228500, loss: 56.078227
# ----
#  ald,
# 			structing_struct
# ----
# ----
#  ald,
# 			structing_struce
# ----
# ----
#  ald,
# 			structing_struct_
# ----
# ----
#  ald,
# 			structing_struct(
# ----
# ----
#  ald,
# 			structing_structi
# ----
# iter 228600, loss: 55.800991
# ----
#  {
# 	struct						struct
# ----
# ----
#  {
# 	struct						structint
# ----
# ----
#  {
# 	struct						struct
# ----
# ----
#  {
# 	struct						struct_ren
# ----
# ----
#  {
# 	struct						struct
# ----
# iter 228700, loss: 55.678633
# ----
#  ITTRINT,	},
# 	struct_rend_
# ----
# ----
#  ITTRINT,	},
# 	struct_rent_
# ----
# ----
#  ITTRINT,	},
# 	struct_rent
# ----
# ----
#  ITTRINT,	},
# 	struct_renti
# ----
# ----
#  ITTRINT,	},
# 	struct_rend
# ----
# iter 228800, loss: 55.310010
# ----
#  CONFINT_INT,	},
# 			return
# ----
# ----
#  CONFINT_INT,	},
# 			ret_rc
# ----
# ----
#  CONFINT_INT,	},
# 			ret_cp
# ----
# ----
#  CONFINT_INT,	},
# 			returc
# ----
# ----
#  CONFINT_INT,	},
# 			returt
# ----
# iter 228900, loss: 54.856620
# ----
#  CONFINT,	},
# 			return"
# ----
# ----
#  CONFINT,	},
# 			return"	}
# ----
# ----
#  CONFINT,	},
# 			return"		}
# ----
# ----
#  CONFINT,	},
# 			return"		=
# ----
# ----
#  CONFINT,	},
# 			return"		i
# ----
# iter 229000, loss: 54.528818
# ----
#  */
# static_uncond_timed_re
# ----
# ----
#  */
# static_uncond_timed_in
# ----
# ----
#  */
# static_uncond_timed_ti
# ----
# ----
#  */
# static_uncond_timed_ta
# ----
# ----
#  */
# static_uncond_timed_lo
# ----
# iter 229100, loss: 54.244840
# ----
#  TLL_INT,	},
# 					struct
# ----
# ----
#  TLL_INT,	},
# 					struct
# ----
# ----
#  TLL_INT,	},
# 					structin
# ----
# ----
#  TLL_INT,	},
# 					struct_r
# ----
# ----
#  TLL_INT,	},
# 					struct_c
# ----
# iter 229200, loss: 54.256832
# ----
#  trace_struct(struct
# ----
# ----
#  trace_struct(struct_time_
# ----
# ----
#  trace_struct(struct_time
# ----
# ----
#  trace_struct(struct_timer
# ----
# ----
#  trace_struct(struct_timed
# ----
# iter 229300, loss: 54.048398
# ----
#  */
# 	struct_time_task_time
# ----
# ----
#  */
# 	struct_time_task_stru
# ----
# ----
#  */
# 	struct_time_task_stat
# ----
# ----
#  */
# 	struct_time_task_strr
# ----
# ----
#  */
# 	struct_time_task_strc
# ----
# iter 229400, loss: 54.136714
# ----
#  conter_ined_long)
# {
# 	stru
# ----
# ----
#  conter_ined_long);
# }
#
# /*
# ----
# ----
#  conter_ined_long)
# {
# 	stat
# ----
# ----
#  conter_ined_long);
# }
#
# /*
#
# ----
# ----
#  conter_ined_long)
# {
# 	strt
# ----
# iter 229500, loss: 54.183588
# ----
#  */
# 	{
# 	struct(timed_struc
# ----
# ----
#  */
# 	{
# 	struct(timed_long
# ----
# ----
#  */
# 	{
# 	struct(timed_long_
# ----
# ----
#  */
# 	{
# 	struct(timed_long)
# ----
# ----
#  */
# 	{
# 	struct(timed_fined
# ----
# iter 229600, loss: 53.930315
# ----
#  block(struct(timed_time,
# ----
# ----
#  block(struct(timed_timed_
# ----
# ----
#  block(struct(timed_timext
# ----
# ----
#  block(struct(timed_timex_
# ----
# ----
#  block(struct(timed_timeru
# ----
# iter 229700, loss: 54.088646
# ----
#  lonstation.
# 			return;
# }
#
# ----
# ----
#  lonstation.
# 			return;
#
#
# ----
# ----
#  lonstation.
# 			return;
# {
#
# ----
# ----
#  lonstation.
# 			return"
#
# ----
# ----
#  lonstation.
# 			return;
#
# ----
# iter 229800, loss: 54.538017
# ----
#  called
# ----
# ----
#  caller
# ----
# ----
#  callen
# ----
# ----
#  calle
# ----
# ----
#  const
# ----
# iter 229900, loss: 54.408541
# ----
#  =
# 			return;
# {
# 	struct
# ----
# ----
#  =
# 			return;
# {
# 	struct_re
# ----
# ----
#  =
# 			return;
# {
# 	return
# ----
# ----
#  =
# 			return;
# {
# 	struct(rc
# ----
# ----
#  =
# 			return;
# {
# 	struct(ri
# ----
# iter 230000, loss: 54.249721
# ----
#  =							return;
# {
# 	struct
# ----
# ----
#  =							return;
# {
# 	return
# ----
# ----
#  =							return;
# {
# 	strunt
# ----
# ----
#  =							return;
# {
# 	strucp
# ----
# ----
#  =							return;
# {
# 	strucc
# ----
# iter 230100, loss: 53.839277
# ----
#  lock_struct;
# }
#
# static
# ----
# ----
#  lock_struct;
# }
#
# struct
# ----
# ----
#  lock_struct;
# }
#
# statit
# ----
# ----
#  lock_struct;
# }
#
# statis
# ----
# ----
#  lock_struct;
# }
#
# statin
# ----
# iter 230200, loss: 53.414457
# ----
#  */
# }
#
# static
#
# ----
# ----
#  */
# }
#
# static
#
# ----
# ----
#  */
# }
#
# static
# 							int
# ----
# ----
#  */
# }
#
# static
# 											d
# ----
# ----
#  */
# }
#
# static
# 											c
# ----
# iter 230300, loss: 52.448843
# ----
#  (struct_pid_task_struct
# ----
# ----
#  (struct_pid_task_structst
# ----
# ----
#  (struct_pid_task_struct(p
# ----
# ----
#  (struct_pid_task_struct_p
# ----
# ----
#  (struct_pid_task_struct(r
# ----
# iter 230400, loss: 52.633859
# ----
#  reading);
# }
#
# static
#
# ----
# ----
#  reading);
# }
#
# static
#
# ----
# ----
#  reading);
# }
#
# static
# 			re
# ----
# ----
#  reading);
# }
#
# static
#
# ----
# ----
#  reading);
# }
#
# static
# 				r
# ----
# iter 230500, loss: 52.921560
# ----
#  the
# 			return;
# }
#
# static
# ----
# ----
#  the
# 			return;
#
# 	return;
#
# ----
# ----
#  the
# 			return;
#
# 	return
#
# ----
# ----
#  the
# 			return;
#
# 	return
# ----
# ----
#  the
# 			return;
# }
#
# static
#
# ----
# iter 230600, loss: 52.770225
# ----
#  istertation
# 						return
# ----
# ----
#  istertation
# 						return;
# ----
# ----
#  istertation
# 						reture
# ----
# ----
#  istertation
# 						returt
# ----
# ----
#  istertation
# 						returc
# ----
# iter 230700, loss: 52.704796
# ----
#  */
# 	return;
# }
#
# static
#
# ----
# ----
#  */
# 	return;
#
# 	return;
#
# 	i
# ----
# ----
#  */
# 	return;
# }
#
# static
#
# ----
# ----
#  */
# 	return;
#
# 	return;
#
# 	r
# ----
# ----
#  */
# 	return;
#
# 	return;
#
# 	s
# ----
# iter 230800, loss: 52.258262
# ----
#  the
# 			intoreaded_lock);
#
# ----
# ----
#  the
# 			intoreaded_lock)
# {
# ----
# ----
#  the
# 			intoreaded_lock,
# ----
# ----
#  the
# 			intoreaded_lock);
# ----
# ----
#  the
# 			intoreaded_lock);
# ----
# iter 230900, loss: 51.936122
# ----
#  */
# 	struct(repurn;
# {
# 	str
# ----
# ----
#  */
# 	struct(repurn;
# }
#
# sta
# ----
# ----
#  */
# 	struct(repurn;
# {
# 	if
# ----
# ----
#  */
# 	struct(repurn;
# }
#
# /*
#
# ----
# ----
#  */
# 	struct(repurn;
# }
#
# /*
# ----
# iter 231000, loss: 51.762710
# ----
#  *trace);
# }
#
# static
# 			ret
# ----
# ----
#  *trace);
# }
#
# static
#
# ----
# ----
#  *trace);
# }
#
# static
#
# ----
# ----
#  *trace);
# }
#
# static
# 					r
# ----
# ----
#  *trace);
# }
#
# static
# 					s
# ----
# iter 231100, loss: 51.225831
# ----
#  the
# 			return;
# {
# 	struct
# ----
# ----
#  the
# 			return;
# {
# 	return
# ----
# ----
#  the
# 			return;
#
# 	return;
#
# ----
# ----
#  the
# 			return;
# {
# 	struct(
# ----
# ----
#  the
# 			return;
# {
# 	struct_
# ----
# iter 231200, loss: 50.752684
# ----
#  returner;
#
# 	return;
# }
#
# /*
# ----
# ----
#  returner;
#
# 	return;
#
# 	if
# ----
# ----
#  returner;
#
# 	return;
# }
#
# st
# ----
# ----
#  returner;
#
# 	return;
#
# 	ret
# ----
# ----
#  returner;
#
# 	return;
#
# 	res
# ----
# iter 231300, loss: 51.052443
# ----
#  */
# 	struct_rest_read(stru
# ----
# ----
#  */
# 	struct_rest_read(strr
# ----
# ----
#  */
# 	struct_rest_read(stri
# ----
# ----
#  */
# 	struct_rest_read(stra
# ----
# ----
#  */
# 	struct_rest_read(strc
# ----
# iter 231400, loss: 50.567524
# ----
#  reader.
# 			return;
# 	retur
# ----
# ----
#  reader.
# 			return;
# }
#
# sta
# ----
# ----
#  reader.
# 			return;
#
# 	retu
# ----
# ----
#  reader.
# 			return;
# }
#
# /*
#
# ----
# ----
#  reader.
# 			return;
# }
#
# /*
# ----
# iter 231500, loss: 50.242008
# ----
#  */
# 	return;
#
# 	return;
# 	re
# ----
# ----
#  */
# 	return;
# }
#
# static
#
# ----
# ----
#  */
# 	return;
# }
#
# static
#
# ----
# ----
#  */
# 	return;
#
# 	return;
#
# 	i
# ----
# ----
#  */
# 	return;
#
# 	return;
#
# 	r
# ----
# iter 231600, loss: 49.560271
# ----
#  {
# 			return;
# 	return;
# 	re
# ----
# ----
#  {
# 		return;
# }
#
# static
#
# ----
# ----
#  {
# 		return;
# }
#
# static
#
# ----
# ----
#  {
# 			return;
# 	return;
#
# 	i
# ----
# ----
#  {
# 			return;
# 	return;
#
# 	r
# ----
# iter 231700, loss: 48.775501
# ----
#  0;
# 			return;
# 			return;
#
# ----
# ----
#  0;
# 			return;
# 			return
# ----
# ----
#  0;
# 			return;
# 			returner
# ----
# ----
#  0;
# 			return;
# 			return_r
# ----
# ----
#  0;
# 			return;
# 			return;
# ----
# iter 231800, loss: 47.944308
# ----
#  struct_resource(struct_re
# ----
# ----
#  struct_resource(struct(re
# ----
# ----
#  struct_resource(struct
# ----
# ----
#  struct_resource(struct(rc
# ----
# ----
#  struct_resource(structirn
# ----
# iter 231900, loss: 47.691882
# ----
#  recource_struct_resource_
# ----
# ----
#  recource_struct_resource(
# ----
# ----
#  recource_struct_resource
# ----
# ----
#  recource_struct_rest_reso
# ----
# ----
#  recource_struct_rest_rest
# ----
# iter 232000, loss: 47.472046
# ----
#  recouster
# ----
# ----
#  resource
# ----
# ----
#  recource
# ----
# ----
#  resources
# ----
# ----
#  recounce
# ----
# iter 232100, loss: 46.774203
# ----
#  *res)
# {
# 	struct_resource(
# ----
# ----
#  *res)
# {
# 	struct_resource_
# ----
# ----
#  *res)
# {
# 	struct_resounce(
# ----
# ----
#  *res)
# {
# 	struct_resource
# ----
# ----
#  *res)
# {
# 	struct_resounce_
# ----
# iter 232200, loss: 46.333921
# ----
#  */
# 	struct_resource(struc
# ----
# ----
#  */
# 	struct_resource
# 			re
# ----
# ----
#  */
# 	struct_resource(strun
# ----
# ----
#  */
# 	struct_resource(strut
# ----
# ----
#  */
# 	struct_resource(strup
# ----
# iter 232300, loss: 46.500613
# ----
#  resource_resource_rest_re
# ----
# ----
#  resource_resource_resourc
# ----
# ----
#  resource_resource_resounc
# ----
# ----
#  resource_resource_resoure
# ----
# ----
#  resource_resource_resoule
# ----
# iter 232400, loss: 46.837164
# ----
#  ret;
#
# 	return;
# }
#
# static
# ----
# ----
#  ret;
#
# 	return;
# }
#
# struct
# ----
# ----
#  ret;
#
# 	return;
#
# 	return;
#
# ----
# ----
#  ret;
#
# 	return;
# }
#
# statis
# ----
# ----
#  ret;
#
# 	return;
# }
#
# static
#
# ----
# iter 232500, loss: 46.727569
# ----
#  */
# static
# 				return;
# }
#
#
# ----
# ----
#  */
# static
# 				return;
# 	}
#
# ----
# ----
#  */
# static
# 				return;
#
# 	i
# ----
# ----
#  */
# static
# 				return;
#
# 	r
# ----
# ----
#  */
# static
# 				return;
#
#
# ----
# iter 232600, loss: 46.859452
# ----
#  struct_request_request_re
# ----
# ----
#  struct_request_restart_re
# ----
# ----
#  struct_request_resounce_r
# ----
# ----
#  struct_request_resounce_c
# ----
# ----
#  struct_request_resounce_s
# ----
# iter 232700, loss: 46.249802
# ----
#  return;
#
# 	return;
#
# 	retur
# ----
# ----
#  return;
#
# 	return;
#
# 	retor
# ----
# ----
#  return;
#
# 	return;
#
# 	retup
# ----
# ----
#  return;
#
# 	return;
#
# 	retum
# ----
# ----
#  return;
#
# 	return;
#
# 	retul
# ----
# iter 232800, loss: 45.885829
# ----
#  next_retounct_request_res
# ----
# ----
#  next_retounct_requent_res
# ----
# ----
#  next_retounct_request_rea
# ----
# ----
#  next_retounct_request_req
# ----
# ----
#  next_retounct_request_ret
# ----
# iter 232900, loss: 45.834524
# ----
#  thale);
# }
#
# static
# 	return
# ----
# ----
#  thale);
# }
#
# static
# 			retu
# ----
# ----
#  thale);
# }
#
# static
# 	returc
# ----
# ----
#  thale);
# }
#
# static
# 	returt
# ----
# ----
#  thale);
# }
#
# static
# 	reture
# ----
# iter 233000, loss: 45.221765
# ----
#  unsigned_long)
# {
# 	struct
# ----
# ----
#  unsigned_long)
# {
# 	return
# ----
# ----
#  unsigned_long)
# 		return;
#
# ----
# ----
#  unsigned_long)
# {
# 	strunt
# ----
# ----
#  unsigned_long)
# {
# 	struct_
# ----
# iter 233100, loss: 44.784869
# ----
#  */
# 		return;
# }
#
# static
#
# ----
# ----
#  */
# 	return;
# }
#
# static
#
# ----
# ----
#  */
# 	return;
# }
#
# static
#
# ----
# ----
#  */
# 		return;
# }
#
# static
#
# ----
# ----
#  */
# 		return;
# }
#
# static
# ----
# iter 233200, loss: 44.503842
# ----
#  struct,
# 	struct_recount_c
# ----
